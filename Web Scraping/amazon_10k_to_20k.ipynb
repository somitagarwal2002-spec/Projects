# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time
import numpy as np
from urllib.parse import urljoin
from datetime import datetime

def get_title(soup):
    try:
        # Outer Tag 
        title = soup.find("span", attrs={"id":'productTitle'})
        
        # Inner String Object
        title_value = title.text
        # Title as a string value
        title_string = title_value.strip()
    except AttributeError:
        title_string = ""
    return title_string

def get_price(soup):
    try:
        price_tag = soup.select_one("span.a-price span.a-offscreen")
        if price_tag and price_tag.text.strip():
            price_text = price_tag.text.strip()
        elif soup.find("span", {"id": "priceblock_ourprice"}):
            price_text = soup.find("span", {"id": "priceblock_ourprice"}).text.strip()
        elif soup.find("span", {"id": "priceblock_dealprice"}):
            price_text = soup.find("span", {"id": "priceblock_dealprice"}).text.strip()
        elif soup.find("span", {"id": "priceToPay"}):
            price_text = soup.find("span", {"id": "priceToPay"}).text.strip()
        elif soup.select_one("span.a-price-whole"):
            whole = soup.select_one("span.a-price-whole").text.replace(",", "").strip()
            fraction_tag = soup.select_one("span.a-price-fraction")
            fraction = fraction_tag.text.strip() if fraction_tag else "00"
            price_text = f"{whole}.{fraction}"
        else:
            return None
        cleaned_price = (
            price_text
            .replace("₹", "")
            .replace(",", "")
            .strip()
                )
        
        return float(cleaned_price)
        
    except Exception:
        return None

def get_rating(soup):
    try:
        rating = soup.find("span", {"class": "a-icon-alt"})
        return rating.text.split(" ")[0]
    except:
        return ""


def get_review_count(soup):
    try:
        # Method 1: Standard review count selector
        review = soup.find("span", {"id": "acrCustomerReviewText"})
        if review:
            review_text = review.text.strip()
            # Brackets aur commas remove karo
            review_number = review_text.split(" ")[0]
            review_number = review_number.replace(",", "").replace("(", "").replace(")", "")
            return int(review_number)
        
        # Method 2: Alternative selector for reviews
        review_alt = soup.select_one("#acrCustomerReviewLink span")
        if review_alt:
            review_text = review_alt.text.strip()
            review_number = review_text.split(" ")[0]
            review_number = review_number.replace(",", "").replace("(", "").replace(")", "")
            return int(review_number)
        
        # Method 3: Another common pattern
        review_count = soup.find("a", {"data-hook": "see-all-reviews-link-foot"})
        if review_count:
            review_text = review_count.find("span").text.strip()
            review_number = review_text.split(" ")[0]
            review_number = review_number.replace(",", "").replace("(", "").replace(")", "")
            return int(review_number)
        
        # Method 4: Check karo agar rating link mein reviews mentioned hain
        rating_link = soup.find("a", {"id": "acrCustomerReviewLink"})
        if rating_link:
            review_text = rating_link.text.strip()
            # "4.5 out of 5 stars    2,031 ratings" jaise format handle karne ke liye
            parts = review_text.split()
            for part in parts:
                cleaned = part.replace(",", "").replace("(", "").replace(")", "")
                if cleaned.isdigit():
                    num = int(cleaned)
                    if num > 10:  # Rating 10 se zyada nahi hoti, toh ye review count hoga
                        return num
            
        return 0  # Agar koi review nahi mila toh 0 return karo
        
    except Exception as e:
        print(f"  ⚠️  Review scraping error: {e}")
        return 0

def get_availability(soup):
    try:
        available = soup.find("div", attrs={'id':'availability'})
        available = available.find("span").string.strip()
    except AttributeError:
        available = "Not Available"	
    return available

def get_discount(soup):
    try:
        discount = soup.find("span", {"class": "savingsPercentage"})
        if discount:
            return discount.text.replace("%", "").replace("-", "").strip()
        return ""
    except:
        return ""

def get_brand(soup):
    try:
        brand = soup.find("a", {"id": "bylineInfo"})
        if brand:
            return brand.text.replace("Visit the", "").replace("Store", "").strip()
        # Alternative method
        brand_alt = soup.find("span", {"class": "a-size-base po-break-word"})
        if brand_alt:
            return brand_alt.text.strip()
        return ""
    except:
        return ""

# %%
if __name__ == '__main__':
    HEADERS = ({'User-Agent':'',
            'Accept-Language': 'en-US, en;q=0.5'})
    BASE_URL = "https://www.amazon.in"
    
    # Price range define karo - 10k to 20k
    MIN_PRICE = 10000
    MAX_PRICE = 20000
    TOTAL_PAGES = 15
    PRICE_LABEL = "10k-20k"
    
    print("="*60)
    print(f"🔍 Amazon Smartphone Scraper - {PRICE_LABEL}")
    print(f"💰 Price Range: ₹{MIN_PRICE:,} - ₹{MAX_PRICE:,}")
    print(f"📄 Pages to Scrape: {TOTAL_PAGES}")
    print("="*60)
    
    product_links = []
    
    # Step 1: Collect all product links
    for page in range(1, TOTAL_PAGES + 1):
        print(f"\n📄 Scraping search page {page}/{TOTAL_PAGES}...")
        
        # Yahan apna custom search URL daalna - page number ke saath
        search_url = f"https://www.amazon.in/s?k=smartphones+10k+to+20k&crid=3MJSS9I3OAR14&sprefix=smartphones+10k+to+20%2Caps%2C407&ref=nb_sb_noss_2&page={page}"
        
        try:
            response = requests.get(search_url, headers=HEADERS, timeout=10)
            if response.status_code != 200:
                print(f"  ⚠️  Page {page} failed with status code: {response.status_code}")
                continue
        except requests.exceptions.RequestException as e:
            print(f"  ⚠️  Page {page} request failed: {e}")
            continue
        
        soup = BeautifulSoup(response.content, "html.parser")
        
        links = soup.find_all("a", attrs={'class':'a-link-normal s-no-outline'})
                               
        for link in links:
            href = link.get("href")
            if href and "/dp/" in href:
                product_links.append(href.split("?")[0])
        
        print(f"  ✓ Found {len(links)} products on page {page}")
        time.sleep(2)  # Be nice to Amazon servers
    
    # Remove duplicates
    product_links = list(set(product_links))
    print(f"\n✅ Total unique products found: {len(product_links)}")
    print("="*60)
    
    # Step 2: Initialize data dictionary
    data = {
        "title": [],
        "price": [],
        "rating": [],
        "reviews": [],
        "discount": [],
        "brand": [],
        "product_url": []
    }
    
    # Step 3: Scrape each product
    print(f"\n🛒 Starting to scrape {len(product_links)} products...")
    print("="*60)
    
    successful_scrapes = 0
    failed_scrapes = 0
    
    for idx, link in enumerate(product_links, start=1):
        product_url = urljoin(BASE_URL, link)
        print(f"📦 [{idx}/{len(product_links)}] Scraping product...")
        
        try:
            product_page = requests.get(product_url, headers=HEADERS, timeout=10)
            if product_page.status_code != 200:
                print(f"  ❌ Failed - Status code: {product_page.status_code}")
                failed_scrapes += 1
                continue
        except Exception as e:
            print(f"  ❌ Failed - Request error: {e}")
            failed_scrapes += 1
            continue
        
        product_soup = BeautifulSoup(product_page.content, "html.parser")
        
        try:
            title = get_title(product_soup)
            cleaned_price = get_price(product_soup)
            rating = get_rating(product_soup)
            reviews = get_review_count(product_soup)
            discount = get_discount(product_soup)
            brand = get_brand(product_soup)
            
            # Data append karo
            data["title"].append(title)
            data["price"].append(cleaned_price)
            data["rating"].append(rating)
            data["reviews"].append(reviews)
            data["discount"].append(discount)
            data["brand"].append(brand)
            data["product_url"].append(product_url)
            
            # Success message with key details
            print(f"  ✓ Success - {title[:50]}... | Price: ₹{cleaned_price} | Reviews: {reviews}")
            successful_scrapes += 1
            
        except Exception as e:
            print(f"  ❌ Failed - Data extraction error: {e}")
            failed_scrapes += 1
            continue
        
        time.sleep(2)  # Delay to avoid getting blocked
    
    # Step 4: Create DataFrame
    print("\n" + "="*60)
    print("📊 Creating DataFrame...")
    amazon_df = pd.DataFrame.from_dict(data)
    
    # Convert to proper data types
    amazon_df["price"] = pd.to_numeric(amazon_df["price"], errors="coerce")
    amazon_df["rating"] = pd.to_numeric(amazon_df["rating"], errors="coerce")
    amazon_df["reviews"] = pd.to_numeric(amazon_df["reviews"], errors="coerce")
    amazon_df["discount"] = pd.to_numeric(amazon_df["discount"], errors="coerce")
    
    # Step 5: Save to CSV
    csv_filename = f"amazon_smartphones_10k_to_20k.csv"
    amazon_df.to_csv(csv_filename, index=False, encoding='utf-8-sig')
    print("Completed")
# Out:
# ============================================================
# 🔍 Amazon Smartphone Scraper - 10k-20k
# 💰 Price Range: ₹10,000 - ₹20,000
# 📄 Pages to Scrape: 15
# ============================================================
#
# 📄 Scraping search page 1/15...
#   ✓ Found 26 products on page 1
#
# 📄 Scraping search page 2/15...
#   ✓ Found 22 products on page 2
#
# 📄 Scraping search page 3/15...
#   ✓ Found 14 products on page 3
#
# 📄 Scraping search page 4/15...
#   ✓ Found 6 products on page 4
#
# 📄 Scraping search page 5/15...
#   ✓ Found 6 products on page 5
#
# 📄 Scraping search page 6/15...
#   ✓ Found 6 products on page 6
#
# 📄 Scraping search page 7/15...
#   ✓ Found 6 products on page 7
#
# 📄 Scraping search page 8/15...
#   ✓ Found 6 products on page 8
#
# 📄 Scraping search page 9/15...
#   ✓ Found 6 products on page 9
#
# 📄 Scraping search page 10/15...
#   ✓ Found 6 products on page 10
#
# 📄 Scraping search page 11/15...
#   ✓ Found 6 products on page 11
#
# 📄 Scraping search page 12/15...
#   ✓ Found 6 products on page 12
#
# 📄 Scraping search page 13/15...
#   ✓ Found 7 products on page 13
#
# 📄 Scraping search page 14/15...
#   ✓ Found 7 products on page 14
#
# 📄 Scraping search page 15/15...
#   ✓ Found 7 products on page 15
#
# ✅ Total unique products found: 54
# ============================================================
#
# 🛒 Starting to scrape 54 products...
# ============================================================
# 📦 [1/54] Scraping product...
#   ✓ Success - realme NARZO 80 Pro 5G (Speed Silver,8GB+128GB) | ... | Price: ₹17999.0 | Reviews: 2035
# 📦 [2/54] Scraping product...
#   ✓ Success - Slide and Learn Multiplication Book for Kids | Int... | Price: ₹849.0 | Reviews: 5
# 📦 [3/54] Scraping product...
#   ✓ Success - Swee10 Natural Stevia Sweetener Pouch 300g | Sugar... | Price: ₹489.0 | Reviews: 351
# 📦 [4/54] Scraping product...
#   ✓ Success - realme NARZO 90 5G (Carbon Black,6GB+128GB) | 7000... | Price: ₹16999.0 | Reviews: 267
# 📦 [5/54] Scraping product...
#   ✓ Success - Lava Blaze AMOLED 2 5G (Sparkling Black, 6 GB RAM,... | Price: ₹12999.0 | Reviews: 75
# 📦 [6/54] Scraping product...
#   ✓ Success - vivo Y100A 5G (Pacific Blue, 8GB RAM, 128GB Storag... | Price: ₹17998.0 | Reviews: 125
# 📦 [7/54] Scraping product...
#   ✓ Success - Oppo A79 5G (Mystery Black, 8GB RAM, 128GB Storage... | Price: ₹16290.0 | Reviews: 612
# 📦 [8/54] Scraping product...
#   ✓ Success - Slide and Learn Multiplication Book for Kids | Int... | Price: ₹849.0 | Reviews: 5
# 📦 [9/54] Scraping product...
#   ✓ Success - realme 13 5G (Speed Green, 8GB RAM, 128GB Storage)... | Price: ₹15999.0 | Reviews: 261
# 📦 [10/54] Scraping product...
#   ✓ Success - realme 15 Lite Smartphone 8+128GB Green, 6.67-inch... | Price: ₹17999.0 | Reviews: 609
# 📦 [11/54] Scraping product...
#   ✓ Success - Samsung Galaxy M35 5G (DayBreak Blue,8GB RAM,128GB... | Price: ₹17499.0 | Reviews: 16854
# 📦 [12/54] Scraping product...
#   ✓ Success - realme 14 Pro 5G Smartphone 6.77 Inch FHD+ Diaplay... | Price: ₹23499.0 | Reviews: 0
# 📦 [13/54] Scraping product...
#   ✓ Success - realme NARZO 90x 5G (Maroon Red,6GB+128GB) | 7000m... | Price: ₹15499.0 | Reviews: 454
# 📦 [14/54] Scraping product...
#   ✓ Success - realme NARZO 80 Pro 5G (Speed Silver,8GB+128GB) | ... | Price: ₹17999.0 | Reviews: 2035
# 📦 [15/54] Scraping product...
#   ✓ Success - Redmi Note 9 Pro (Glacier White, 4GB RAM, 64GB Sto... | Price: ₹13999.0 | Reviews: 137328
# 📦 [16/54] Scraping product...
#   ✓ Success - Slide and Learn Multiplication Book for Kids | Int... | Price: ₹849.0 | Reviews: 5
# 📦 [17/54] Scraping product...
#   ✓ Success - REDMI Note 15 5G (Mist Purple, 8GB RAM 256GB Stora... | Price: ₹24999.0 | Reviews: 298
# 📦 [18/54] Scraping product...
#   ✓ Success - iQOO Z9 5G (Graphene Blue, 8GB RAM, 256GB Storage)... | Price: ₹19499.0 | Reviews: 6387
# 📦 [19/54] Scraping product...
#   ✓ Success - realme 15X 5G Smartphone 8+256GB Marine Blue, 6.8-... | Price: ₹21999.0 | Reviews: 188
# 📦 [20/54] Scraping product...
#   ✓ Success - Redmi A4 5G (Starry Black, 6GB RAM, 128GB Storage)... | Price: ₹10999.0 | Reviews: 12168
# 📦 [21/54] Scraping product...
#   ✓ Success - Swee10 Natural Stevia Sweetener Pouch 300g | Sugar... | Price: ₹489.0 | Reviews: 351
# 📦 [22/54] Scraping product...
#   ✓ Success - realme narzo 90 5G (Flowing Silver,8GB+128GB) | 70... | Price: ₹18499.0 | Reviews: 267
# 📦 [23/54] Scraping product...
#   ✓ Success - realme C85 5G Smartphone 6+128GB Purple, 6.8inch S... | Price: ₹18999.0 | Reviews: 172
# 📦 [24/54] Scraping product...
#   ✓ Success - Redmi Note 12 5G Mystique Blue 4GB RAM 128GB ROM |... | Price: ₹12990.0 | Reviews: 1370
# 📦 [25/54] Scraping product...
#   ✓ Success - Slide and Learn Multiplication Book for Kids | Int... | Price: ₹849.0 | Reviews: 5
# 📦 [26/54] Scraping product...
#   ✓ Success - Pova 7 Pro 5G (Geek Black, 8GB+128GB) with No Cost... | Price: ₹17299.0 | Reviews: 25
# 📦 [27/54] Scraping product...
#   ✓ Success - realme P3 5G with 6.67″ FHD+ 120Hz AMOLED Display ... | Price: ₹18999.0 | Reviews: 60
# 📦 [28/54] Scraping product...
#   ✓ Success - realme NARZO 70x 5G (Ice Blue, 8GB RAM,128GB Stora... | Price: ₹17999.0 | Reviews: 9500
# 📦 [29/54] Scraping product...
#   ✓ Success - Slide and Learn Multiplication Book for Kids | Int... | Price: ₹849.0 | Reviews: 5
# 📦 [30/54] Scraping product...
#   ✓ Success - realme NARZO 90x 5G (Maroon Red, 8GB+128GB) | 7000... | Price: ₹16999.0 | Reviews: 454
# 📦 [31/54] Scraping product...
#   ✓ Success - Samsung Galaxy A23 5G, Silver (6GB, 128GB Storage)... | Price: ₹23990.0 | Reviews: 1291
# 📦 [32/54] Scraping product...
#   ✓ Success - realme NARZO 70 Turbo 5G (Turbo Purple,6GB RAM,128... | Price: ₹16968.0 | Reviews: 5548
# 📦 [33/54] Scraping product...
#   ✓ Success - realme NARZO 90x 5G (Nitro Blue,6GB+128GB) | 7000m... | Price: ₹15499.0 | Reviews: 454
# 📦 [34/54] Scraping product...
#   ✓ Success - Slide and Learn Multiplication Book for Kids | Int... | Price: ₹849.0 | Reviews: 5
# 📦 [35/54] Scraping product...
#   ✓ Success - realme 15X 5G Smartphone 8GB RAM 128GB ROM, 6.8 in... | Price: ₹17740.0 | Reviews: 190
# 📦 [36/54] Scraping product...
#   ✓ Success - Redmi Note 11T 5G (Aquamarine Blue, 8GB RAM, 128GB... | Price: ₹19999.0 | Reviews: 2494
# 📦 [37/54] Scraping product...
#   ✓ Success - realme 15T 5G Smartphone 7000mAh Battery 6.57 inch... | Price: ₹19399.0 | Reviews: 182
# 📦 [38/54] Scraping product...
#   ✓ Success - Slide and Learn Multiplication Book for Kids | Int... | Price: ₹849.0 | Reviews: 5
# 📦 [39/54] Scraping product...
#   ✓ Success - Slide and Learn Multiplication Book for Kids | Int... | Price: ₹849.0 | Reviews: 5
# 📦 [40/54] Scraping product...
#   ✓ Success - Slide and Learn Multiplication Book for Kids | Int... | Price: ₹849.0 | Reviews: 5
# 📦 [41/54] Scraping product...
#   ✓ Success - Slide and Learn Multiplication Book for Kids | Int... | Price: ₹849.0 | Reviews: 5
# 📦 [42/54] Scraping product...
#   ✓ Success - REDMI 15C 5G Dusk Purple 6GB + 128GB | Royale Desi... | Price: ₹13999.0 | Reviews: 263
# 📦 [43/54] Scraping product...
#   ✓ Success - realme 15 Lite 5G Smartphone 8+128GB Elect Purple,... | Price: ₹15999.0 | Reviews: 0
# 📦 [44/54] Scraping product...
#   ✓ Success - realme 15X 5G Smartphone 8GB RAM 128GB ROM, 6.8 in... | Price: ₹17740.0 | Reviews: 190
# 📦 [45/54] Scraping product...
#   ✓ Success - iQOO Z9 5G (Graphene Blue, 8GB RAM, 128GB Storage)... | Price: ₹19499.0 | Reviews: 2012
# 📦 [46/54] Scraping product...
#   ✓ Success - Redmi 15 5G Frosted White 8GB + 128GB | Segment's ... | Price: ₹16999.0 | Reviews: 1343
# 📦 [47/54] Scraping product...
#   ✓ Success - Realme P3 Pro 5G (Saturn Brown, 8GB RAM, 128GB Sto... | Price: ₹21690.0 | Reviews: 8
# 📦 [48/54] Scraping product...
#   ✓ Success - Slide and Learn Multiplication Book for Kids | Int... | Price: ₹849.0 | Reviews: 5
# 📦 [49/54] Scraping product...
#   ✓ Success - realme NARZO 80 Lite 5G (Onyx Black, 6GB+128GB) | ... | Price: ₹12499.0 | Reviews: 3403
# 📦 [50/54] Scraping product...
#   ✓ Success - realme NARZO 90x 5G (Maroon Red, 8GB+128GB) | 7000... | Price: ₹16999.0 | Reviews: 454
# 📦 [51/54] Scraping product...
#   ✓ Success - Samsung Galaxy M15 5G (Blue Topaz,6GB RAM,128GB St... | Price: ₹16999.0 | Reviews: 3010
# 📦 [52/54] Scraping product...
#   ✓ Success - Slide and Learn Multiplication Book for Kids | Int... | Price: ₹849.0 | Reviews: 5
# 📦 [53/54] Scraping product...
#   ✓ Success - MI 10i 5G (Atlantic Blue, 8GB RAM, 128GB Storage) ... | Price: ₹23999.0 | Reviews: 36009
# 📦 [54/54] Scraping product...
#   ✓ Success - Redmi Note 10S (Deep Sea Blue, 8GB RAM,128 GB Stor... | Price: ₹17999.0 | Reviews: 1151
#
# ============================================================
# 📊 Creating DataFrame...
# Completed
