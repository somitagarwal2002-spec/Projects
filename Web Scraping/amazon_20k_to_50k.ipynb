# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time
import numpy as np
from urllib.parse import urljoin
from datetime import datetime

def get_title(soup):
    try:
        # Outer Tag 
        title = soup.find("span", attrs={"id":'productTitle'})
        
        # Inner String Object
        title_value = title.text
        # Title as a string value
        title_string = title_value.strip()
    except AttributeError:
        title_string = ""
    return title_string

def get_price(soup):
    try:
        price_tag = soup.select_one("span.a-price span.a-offscreen")
        if price_tag and price_tag.text.strip():
            price_text = price_tag.text.strip()
        elif soup.find("span", {"id": "priceblock_ourprice"}):
            price_text = soup.find("span", {"id": "priceblock_ourprice"}).text.strip()
        elif soup.find("span", {"id": "priceblock_dealprice"}):
            price_text = soup.find("span", {"id": "priceblock_dealprice"}).text.strip()
        elif soup.find("span", {"id": "priceToPay"}):
            price_text = soup.find("span", {"id": "priceToPay"}).text.strip()
        elif soup.select_one("span.a-price-whole"):
            whole = soup.select_one("span.a-price-whole").text.replace(",", "").strip()
            fraction_tag = soup.select_one("span.a-price-fraction")
            fraction = fraction_tag.text.strip() if fraction_tag else "00"
            price_text = f"{whole}.{fraction}"
        else:
            return None
        cleaned_price = (
            price_text
            .replace("₹", "")
            .replace(",", "")
            .strip()
                )
        
        return float(cleaned_price)
        
    except Exception:
        return None

def get_rating(soup):
    try:
        rating = soup.find("span", {"class": "a-icon-alt"})
        return rating.text.split(" ")[0]
    except:
        return ""


def get_review_count(soup):
    try:
        # Method 1: Standard review count selector
        review = soup.find("span", {"id": "acrCustomerReviewText"})
        if review:
            review_text = review.text.strip()
            # Brackets aur commas remove karo
            review_number = review_text.split(" ")[0]
            review_number = review_number.replace(",", "").replace("(", "").replace(")", "")
            return int(review_number)
        
        # Method 2: Alternative selector for reviews
        review_alt = soup.select_one("#acrCustomerReviewLink span")
        if review_alt:
            review_text = review_alt.text.strip()
            review_number = review_text.split(" ")[0]
            review_number = review_number.replace(",", "").replace("(", "").replace(")", "")
            return int(review_number)
        
        # Method 3: Another common pattern
        review_count = soup.find("a", {"data-hook": "see-all-reviews-link-foot"})
        if review_count:
            review_text = review_count.find("span").text.strip()
            review_number = review_text.split(" ")[0]
            review_number = review_number.replace(",", "").replace("(", "").replace(")", "")
            return int(review_number)
        
        # Method 4: Check karo agar rating link mein reviews mentioned hain
        rating_link = soup.find("a", {"id": "acrCustomerReviewLink"})
        if rating_link:
            review_text = rating_link.text.strip()
            # "4.5 out of 5 stars    2,031 ratings" jaise format handle karne ke liye
            parts = review_text.split()
            for part in parts:
                cleaned = part.replace(",", "").replace("(", "").replace(")", "")
                if cleaned.isdigit():
                    num = int(cleaned)
                    if num > 10:  # Rating 10 se zyada nahi hoti, toh ye review count hoga
                        return num
            
        return 0  # Agar koi review nahi mila toh 0 return karo
        
    except Exception as e:
        print(f"  ⚠️  Review scraping error: {e}")
        return 0

def get_availability(soup):
    try:
        available = soup.find("div", attrs={'id':'availability'})
        available = available.find("span").string.strip()
    except AttributeError:
        available = "Not Available"	
    return available

def get_discount(soup):
    try:
        discount = soup.find("span", {"class": "savingsPercentage"})
        if discount:
            return discount.text.replace("%", "").replace("-", "").strip()
        return ""
    except:
        return ""

def get_brand(soup):
    try:
        brand = soup.find("a", {"id": "bylineInfo"})
        if brand:
            return brand.text.replace("Visit the", "").replace("Store", "").strip()
        # Alternative method
        brand_alt = soup.find("span", {"class": "a-size-base po-break-word"})
        if brand_alt:
            return brand_alt.text.strip()
        return ""
    except:
        return ""

# %%
if __name__ == '__main__':
    HEADERS = ({'User-Agent':'',
            'Accept-Language': 'en-US, en;q=0.5'})
    BASE_URL = "https://www.amazon.in"
    
    # Price range define karo - 20k to 50k
    MIN_PRICE = 20000
    MAX_PRICE = 50000
    TOTAL_PAGES = 15
    PRICE_LABEL = "20k-50k"
    
    print("="*60)
    print(f"🔍 Amazon Smartphone Scraper - {PRICE_LABEL}")
    print(f"💰 Price Range: ₹{MIN_PRICE:,} - ₹{MAX_PRICE:,}")
    print(f"📄 Pages to Scrape: {TOTAL_PAGES}")
    print("="*60)
    
    product_links = []
    
    # Step 1: Collect all product links
    for page in range(1, TOTAL_PAGES + 1):
        print(f"\n📄 Scraping search page {page}/{TOTAL_PAGES}...")
        
        # Yahan apna custom search URL daalna - page number ke saath
        search_url = f"https://www.amazon.in/s?k=smartphones+20k+to+50k&crid=1KDJ44NP04IMB&sprefix=smartphones+20k+to+0k%2Caps%2C380&ref=nb_sb_noss&page={page}"
        
        try:
            response = requests.get(search_url, headers=HEADERS, timeout=10)
            if response.status_code != 200:
                print(f"  ⚠️  Page {page} failed with status code: {response.status_code}")
                continue
        except requests.exceptions.RequestException as e:
            print(f"  ⚠️  Page {page} request failed: {e}")
            continue
        
        soup = BeautifulSoup(response.content, "html.parser")
        
        links = soup.find_all("a", attrs={'class':'a-link-normal s-no-outline'})
                               
        for link in links:
            href = link.get("href")
            if href and "/dp/" in href:
                product_links.append(href.split("?")[0])
        
        print(f"  ✓ Found {len(links)} products on page {page}")
        time.sleep(2)  # Be nice to Amazon servers
    
    # Remove duplicates
    product_links = list(set(product_links))
    print(f"\n✅ Total unique products found: {len(product_links)}")
    print("="*60)
    
    # Step 2: Initialize data dictionary
    data = {
        "title": [],
        "price": [],
        "rating": [],
        "reviews": [],
        "discount": [],
        "brand": [],
        "product_url": []
    }
    
    # Step 3: Scrape each product
    print(f"\n🛒 Starting to scrape {len(product_links)} products...")
    print("="*60)
    
    successful_scrapes = 0
    failed_scrapes = 0
    
    for idx, link in enumerate(product_links, start=1):
        product_url = urljoin(BASE_URL, link)
        print(f"📦 [{idx}/{len(product_links)}] Scraping product...")
        
        try:
            product_page = requests.get(product_url, headers=HEADERS, timeout=10)
            if product_page.status_code != 200:
                print(f"  ❌ Failed - Status code: {product_page.status_code}")
                failed_scrapes += 1
                continue
        except Exception as e:
            print(f"  ❌ Failed - Request error: {e}")
            failed_scrapes += 1
            continue
        
        product_soup = BeautifulSoup(product_page.content, "html.parser")
        
        try:
            title = get_title(product_soup)
            cleaned_price = get_price(product_soup)
            rating = get_rating(product_soup)
            reviews = get_review_count(product_soup)
            discount = get_discount(product_soup)
            brand = get_brand(product_soup)
            
            # Data append karo
            data["title"].append(title)
            data["price"].append(cleaned_price)
            data["rating"].append(rating)
            data["reviews"].append(reviews)
            data["discount"].append(discount)
            data["brand"].append(brand)
            data["product_url"].append(product_url)
            
            # Success message with key details
            print(f"  ✓ Success - {title[:50]}... | Price: ₹{cleaned_price} | Reviews: {reviews}")
            successful_scrapes += 1
            
        except Exception as e:
            print(f"  ❌ Failed - Data extraction error: {e}")
            failed_scrapes += 1
            continue
        
        time.sleep(2)  # Delay to avoid getting blocked
    
    # Step 4: Create DataFrame
    print("\n" + "="*60)
    print("📊 Creating DataFrame...")
    amazon_df = pd.DataFrame.from_dict(data)
    
    # Convert to proper data types
    amazon_df["price"] = pd.to_numeric(amazon_df["price"], errors="coerce")
    amazon_df["rating"] = pd.to_numeric(amazon_df["rating"], errors="coerce")
    amazon_df["reviews"] = pd.to_numeric(amazon_df["reviews"], errors="coerce")
    amazon_df["discount"] = pd.to_numeric(amazon_df["discount"], errors="coerce")
    
    # Step 5: Save to CSV
    csv_filename = f"amazon_smartphones_20k_to_50k.csv"
    amazon_df.to_csv(csv_filename, index=False, encoding='utf-8-sig')
    print("Completed")
# Out:
# ============================================================
# 🔍 Amazon Smartphone Scraper - 20k-50k
# 💰 Price Range: ₹20,000 - ₹50,000
# 📄 Pages to Scrape: 15
# ============================================================
#
# 📄 Scraping search page 1/15...
#   ✓ Found 25 products on page 1
#
# 📄 Scraping search page 2/15...
#   ✓ Found 23 products on page 2
#
# 📄 Scraping search page 3/15...
#   ✓ Found 23 products on page 3
#
# 📄 Scraping search page 4/15...
#   ✓ Found 23 products on page 4
#
# 📄 Scraping search page 5/15...
#   ✓ Found 20 products on page 5
#
# 📄 Scraping search page 6/15...
#   ✓ Found 7 products on page 6
#
# 📄 Scraping search page 7/15...
#   ✓ Found 7 products on page 7
#
# 📄 Scraping search page 8/15...
#   ✓ Found 7 products on page 8
#
# 📄 Scraping search page 9/15...
#   ✓ Found 7 products on page 9
#
# 📄 Scraping search page 10/15...
#   ✓ Found 7 products on page 10
#
# 📄 Scraping search page 11/15...
#   ✓ Found 7 products on page 11
#
# 📄 Scraping search page 12/15...
#   ✓ Found 7 products on page 12
#
# 📄 Scraping search page 13/15...
#   ✓ Found 8 products on page 13
#
# 📄 Scraping search page 14/15...
#   ✓ Found 8 products on page 14
#
# 📄 Scraping search page 15/15...
#   ✓ Found 8 products on page 15
#
# ✅ Total unique products found: 91
# ============================================================
#
# 🛒 Starting to scrape 91 products...
# ============================================================
# 📦 [1/91] Scraping product...
#   ✓ Success - REDMI Note 15 Pro+ 5G (Coffee Mocha, 8GB + 256GB) ... | Price: ₹37999.0 | Reviews: 42
# 📦 [2/91] Scraping product...
#   ✓ Success - iQOO Z10R 5G (Aquamarine, 8GB RAM, 256GB Storage) ... | Price: ₹22998.0 | Reviews: 3466
# 📦 [3/91] Scraping product...
#   ✓ Success - Selfie Stick Tripod Portable 50" Extendable Blueto... | Price: ₹948.0 | Reviews: 76
# 📦 [4/91] Scraping product...
#   ✓ Success - Pova 7 Pro 5G (Geek Black, 8GB+256GB) with No Cost... | Price: ₹18249.0 | Reviews: 25
# 📦 [5/91] Scraping product...
#   ✓ Success - Nothing Phone 3A Pro 8/128 GB Gray... | Price: ₹30490.0 | Reviews: 98
# 📦 [6/91] Scraping product...
#   ✓ Success - iQOO Z9 5G (Graphene Blue, 8GB RAM, 256GB Storage)... | Price: ₹19499.0 | Reviews: 6387
# 📦 [7/91] Scraping product...
#   ✓ Success - World’s Greatest Books For Personal Growth & Wealt... | Price: ₹349.0 | Reviews: 28116
# 📦 [8/91] Scraping product...
#   ✓ Success - realme 14 Pro 5G Smartphone 6.77 Inch FHD+ Diaplay... | Price: ₹23499.0 | Reviews: 0
# 📦 [9/91] Scraping product...
#   ✓ Success - realme GT 7T Smartphone 6.8 Inch Display 120Hz Ref... | Price: ₹29999.0 | Reviews: 31
# 📦 [10/91] Scraping product...
#   ✓ Success - OnePlus Nord CE5 | MediaTek Dimensity | Massive 71... | Price: ₹26999.0 | Reviews: 4599
# 📦 [11/91] Scraping product...
#   ✓ Success - Selfie Stick Tripod Portable 50" Extendable Blueto... | Price: ₹948.0 | Reviews: 76
# 📦 [12/91] Scraping product...
#   ✓ Success - vivo Y300 Plus 5G (Silk Black, 8GB RAM, 128GB Stor... | Price: ₹22300.0 | Reviews: 47
# 📦 [13/91] Scraping product...
#   ✓ Success - Edge 50 Pro 5G 125W Charger 12GB RAM, 256GB Storag... | Price: ₹25999.0 | Reviews: 0
# 📦 [14/91] Scraping product...
#   ✓ Success - Nothing Phone (3A) 5G (Blue, 8GB RAM, 128GB Storag... | Price: ₹24999.0 | Reviews: 103
# 📦 [15/91] Scraping product...
#   ✓ Success - realme 16 Pro+ 5G Smartphone 8+256GB Grey, 144Hz A... | Price: ₹45999.0 | Reviews: 48
# 📦 [16/91] Scraping product...
#   ✓ Success - Motorola Edge 60 Pro 5G (Pantone Sparkling Grape, ... | Price: ₹32999.0 | Reviews: 51
# 📦 [17/91] Scraping product...
#   ✓ Success - realme 15X 5G Smartphone 8+256GB Marine Blue, 6.8-... | Price: ₹21999.0 | Reviews: 188
# 📦 [18/91] Scraping product...
#   ✓ Success - realme 16 Pro+ 5G Smartphone 12+256GB Gold, 144Hz ... | Price: ₹48999.0 | Reviews: 48
# 📦 [19/91] Scraping product...
#   ✓ Success - Samsung Galaxy A36 5G (Awesome Lavender, 8GB, 256G... | Price: ₹35499.0 | Reviews: 560
# 📦 [20/91] Scraping product...
#   ✓ Success - realme 15 pro 5G Smartphone 8GB RAM 256GB ROM Snap... | Price: ₹31999.0 | Reviews: 57
# 📦 [21/91] Scraping product...
#   ✓ Success - Samsung Galaxy A35 5G (Awesome Lilac, 8GB RAM, 128... | Price: ₹20735.0 | Reviews: 1267
# 📦 [22/91] Scraping product...
#   ✓ Success - Selfie Stick Tripod Portable 50" Extendable Blueto... | Price: ₹948.0 | Reviews: 76
# 📦 [23/91] Scraping product...
#   ✓ Success - realme 15 5G Smartphone 8+256GB Green,144Hz HyperG... | Price: ₹30999.0 | Reviews: 219
# 📦 [24/91] Scraping product...
#   ✓ Success - Oppo A5 5G (Mist White, 8GB RAM, 128GB Storage) wi... | Price: ₹17999.0 | Reviews: 77
# 📦 [25/91] Scraping product...
#   ✓ Success - Selfie Stick Tripod Portable 50" Extendable Blueto... | Price: ₹948.0 | Reviews: 76
# 📦 [26/91] Scraping product...
#   ✓ Success - vivo Y200 Pro 5G (Silk Green, 8GB RAM, 128GB Stora... | Price: ₹22999.0 | Reviews: 92
# 📦 [27/91] Scraping product...
#   ✓ Success - vivo X300 Pro 5G (Dune Gold, 16GB RAM, 512GB Stora... | Price: ₹109998.0 | Reviews: 151
# 📦 [28/91] Scraping product...
#   ✓ Success - VIVO X200 Pro 5G (16GB RAM | 512GB Storage | Cosmo... | Price: ₹79999.0 | Reviews: 1
# 📦 [29/91] Scraping product...
#   ✓ Success - Selfie Stick Tripod Portable 50" Extendable Blueto... | Price: ₹948.0 | Reviews: 76
# 📦 [30/91] Scraping product...
#   ✓ Success - Oppo Reno15Pro 5G (Cocoa Brown, 12GB RAM, 256GB St... | Price: ₹67999.0 | Reviews: 26
# 📦 [31/91] Scraping product...
#   ✓ Success - Redmi Note 9 Pro (Glacier White, 4GB RAM, 64GB Sto... | Price: ₹13999.0 | Reviews: 137328
# 📦 [32/91] Scraping product...
#   ✓ Success - Oppo Find X9 Pro 5G (Titanium Charcoal, 16GB RAM, ... | Price: ₹109999.0 | Reviews: 47
# 📦 [33/91] Scraping product...
#   ✓ Success - realme GT 7T Smartphone 6.8 Inch Display 120Hz Ref... | Price: ₹29999.0 | Reviews: 31
# 📦 [34/91] Scraping product...
#   ✓ Success - realme GT 6T 5G (Razor Green,8GB RAM+256GB Storage... | Price: ₹28999.0 | Reviews: 5334
# 📦 [35/91] Scraping product...
#   ✓ Success - Samsung Galaxy A36 5G (Awesome Black, 8GB, 256GB) ... | Price: ₹35499.0 | Reviews: 560
# 📦 [36/91] Scraping product...
#   ✓ Success - REDMI Note 15 Pro 5G (Silver Ash, 8GB+128GB) | 200... | Price: ₹29999.0 | Reviews: 23
# 📦 [37/91] Scraping product...
#   ✓ Success - OnePlus 10R 5G Prime Edition (Prime Blue, 8GB RAM,... | Price: ₹26999.0 | Reviews: 16508
# 📦 [38/91] Scraping product...
#   ✓ Success - Oppo F27 Pro+ 5G (Dusk Pink, 8GB RAM, 256GB Storag... | Price: ₹34999.0 | Reviews: 853
# 📦 [39/91] Scraping product...
#   ✓ Success - VIVO X90 Pro (Legendary Black) – 12GB RAM, 256GB S... | Price: ₹54990.0 | Reviews: 2
# 📦 [40/91] Scraping product...
#   ✓ Success - OnePlus 10T 5G (Jade Green, 8GB RAM, 128GB Storage... | Price: ₹32999.0 | Reviews: 4891
# 📦 [41/91] Scraping product...
#   ✓ Success - Samsung Galaxy A55 5G (Awesome Navy, 8GB RAM, 256G... | Price: ₹27999.0 | Reviews: 5648
# 📦 [42/91] Scraping product...
#   ✓ Success - Vivo V60 5G (Mist Gray, 8GB RAM, 256GB Storage) wi... | Price: ₹38999.0 | Reviews: 812
# 📦 [43/91] Scraping product...
#   ✓ Success - iQOO 11 5G (Alpha, 16GB RAM, 256 GB Storage) | Sna... | Price: ₹44999.0 | Reviews: 1289
# 📦 [44/91] Scraping product...
#   ✓ Success - realme Smartphone 15 pro 5G, 12GB RAM 256GB ROM 6.... | Price: ₹35999.0 | Reviews: 66
# 📦 [45/91] Scraping product...
#   ✓ Success - realme GT 6T 5G (Razor Green,12GB RAM+256GB Storag... | Price: ₹30999.0 | Reviews: 0
# 📦 [46/91] Scraping product...
#   ✓ Success - vivo V60e 5G (Elite Purple, 8GB RAM, 128GB Storage... | Price: ₹31999.0 | Reviews: 386
# 📦 [47/91] Scraping product...
#   ✓ Success - realme GT7 Pro 5G Smartphone 16+512 Mars Orange, 6... | Price: ₹55990.0 | Reviews: 162
# 📦 [48/91] Scraping product...
#   ✓ Success - POVA Curve 5G (Magic Silver, 8GB+256GB)... | Price: ₹18199.0 | Reviews: 217
# 📦 [49/91] Scraping product...
#   ✓ Success - Selfie Stick Tripod Portable 50" Extendable Blueto... | Price: ₹948.0 | Reviews: 76
# 📦 [50/91] Scraping product...
#   ✓ Success - realme GT 6T 5G (Fluid Silver,8GB RAM+256GB Storag... | Price: ₹28499.0 | Reviews: 5
# 📦 [51/91] Scraping product...
#   ✓ Success - Samsung Galaxy S24 FE 5G AI Smartphone (Mint, 8GB ... | Price: ₹39799.0 | Reviews: 886
# 📦 [52/91] Scraping product...
#   ✓ Success - Motorola Edge 50 Neo 5G (Pantone Nautical Blue, 8G... | Price: ₹22990.0 | Reviews: 298
# 📦 [53/91] Scraping product...
#   ✓ Success - Vivo X200 5G (Cosmos Black, 12GB RAM, 256GB Storag... | Price: ₹65999.0 | Reviews: 199
# 📦 [54/91] Scraping product...
#   ✓ Success - Samsung Galaxy S25 FE 5G Smartphone with Galaxy AI... | Price: ₹57990.0 | Reviews: 41
# 📦 [55/91] Scraping product...
#   ✓ Success - iQOO Neo 10R 5G (Moonknight Titanium, 8GB RAM, 256... | Price: ₹28998.0 | Reviews: 6246
# 📦 [56/91] Scraping product...
#   ✓ Success - Selfie Stick Tripod Portable 50" Extendable Blueto... | Price: ₹948.0 | Reviews: 76
# 📦 [57/91] Scraping product...
#   ✓ Success - OnePlus 10R 5G (Sierra Black, 12GB RAM, 256GB Stor... | Price: ₹29999.0 | Reviews: 4241
# 📦 [58/91] Scraping product...
#   ✓ Success - Selfie Stick Tripod Portable 50" Extendable Blueto... | Price: ₹948.0 | Reviews: 76
# 📦 [59/91] Scraping product...
#   ✓ Success - Samsung Galaxy S24 5G (Cobalt Violet, 8GB RAM, 128... | Price: ₹41994.0 | Reviews: 2113
# 📦 [60/91] Scraping product...
#   ✓ Success - Samsung Galaxy A36 5G (Awesome Lavender, 8GB, 256G... | Price: ₹35499.0 | Reviews: 560
# 📦 [61/91] Scraping product...
#   ✓ Success - Motorola Edge 50 Fusion 5G (Forest Green, 8GB RAM ... | Price: ₹19990.0 | Reviews: 214
# 📦 [62/91] Scraping product...
#   ✓ Success - Motorola Edge 60 Pro (Pantone Shadow, 256 GB) (8 G... | Price: ₹29999.0 | Reviews: 234
# 📦 [63/91] Scraping product...
#   ✓ Success - Oppo A79 5G (Mystery Black, 8GB RAM, 128GB Storage... | Price: ₹16290.0 | Reviews: 612
# 📦 [64/91] Scraping product...
#   ✓ Success - Realme GT Neo 3 (Nitro Blue, 8GB RAM, 256GB Storag... | Price: ₹23499.0 | Reviews: 60
# 📦 [65/91] Scraping product...
#   ✓ Success - Selfie Stick Tripod Portable 50" Extendable Blueto... | Price: ₹948.0 | Reviews: 76
# 📦 [66/91] Scraping product...
#   ✓ Success - realme 15X 5G Smartphone 8GB RAM 128GB ROM, 6.8 in... | Price: ₹17740.0 | Reviews: 190
# 📦 [67/91] Scraping product...
#   ✓ Success - Samsung Galaxy S25+ 5G AI Smartphone (Navy, 12GB R... | Price: ₹99999.0 | Reviews: 242
# 📦 [68/91] Scraping product...
#   ✓ Success - realme 15 Smartphone 5G 12GB RAM 256GB ROM 6.8" AM... | Price: ₹30999.0 | Reviews: 49
# 📦 [69/91] Scraping product...
#   ✓ Success - Motorola Edge 60 Fusion 5G Smartphone with 6.67" 1... | Price: ₹21277.0 | Reviews: 2431
# 📦 [70/91] Scraping product...
#   ✓ Success - Selfie Stick Tripod Portable 50" Extendable Blueto... | Price: ₹948.0 | Reviews: 76
# 📦 [71/91] Scraping product...
#   ✓ Success - Nothing Phone (3), White (12GB, 256GB)... | Price: ₹49499.0 | Reviews: 36
# 📦 [72/91] Scraping product...
#   ✓ Success - Selfie Stick Tripod Portable 50" Extendable Blueto... | Price: ₹948.0 | Reviews: 76
# 📦 [73/91] Scraping product...
#   ✓ Success - OnePlus Nord 3 5G (Tempest Gray, 8GB RAM, 128GB St... | Price: ₹26999.0 | Reviews: 8029
# 📦 [74/91] Scraping product...
#   ✓ Success - Oppo Reno15Pro 5G (Cocoa Brown, 12GB RAM, 256GB St... | Price: ₹67999.0 | Reviews: 26
# 📦 [75/91] Scraping product...
#   ✓ Success - realme 16 Pro+ 5G Smartphone 12+256GB Gold, 144Hz ... | Price: ₹48999.0 | Reviews: 48
# 📦 [76/91] Scraping product...
#   ✓ Success - REDMI Note 15 Pro+ 5G (Mirage Blue, 8GB + 256GB) |... | Price: ₹37999.0 | Reviews: 42
# 📦 [77/91] Scraping product...
#   ✓ Success - Selfie Stick Tripod Portable 50" Extendable Blueto... | Price: ₹948.0 | Reviews: 76
# 📦 [78/91] Scraping product...
#   ✓ Success - Motorola Edge 70 (Grey, 8GB RAM, 256GB Storage)... | Price: ₹30945.0 | Reviews: 12
# 📦 [79/91] Scraping product...
#   ✓ Success - Oppo F25 Pro 5G (Lava Red, 8GB RAM, 256GB Storage)... | Price: ₹30999.0 | Reviews: 639
# 📦 [80/91] Scraping product...
#   ✓ Success - Motorola Edge 40 5G (Nebula Green, 8GB RAM, 256GB ... | Price: ₹33365.0 | Reviews: 84
# 📦 [81/91] Scraping product...
#   ✓ Success - realme 16 Pro 5G Smartphone 8+256GB Master Gold, 1... | Price: ₹36999.0 | Reviews: 49
# 📦 [82/91] Scraping product...
#   ✓ Success - OnePlus 11 5G (Eternal Green, 8GB RAM, 128GB Stora... | Price: ₹32499.0 | Reviews: 6706
# 📦 [83/91] Scraping product...
#   ✓ Success - OnePlus 15R | 12GB+256GB | Charcoal Black | World'... | Price: ₹47999.0 | Reviews: 632
# 📦 [84/91] Scraping product...
#   ✓ Success - iQOO Neo 10 (Inferno Red, 12GB RAM, 256GB Storage)... | Price: ₹38998.0 | Reviews: 4350
# 📦 [85/91] Scraping product...
#   ✓ Success - Nothing Phone (3a) Lite 5G (White, 8GB RAM, 256GB ... | Price: ₹23420.0 | Reviews: 5050
# 📦 [86/91] Scraping product...
#   ✓ Success - REDMI Note 15 Pro 5G (Silver Ash 8GB+256GB) | 200M... | Price: ₹31999.0 | Reviews: 23
# 📦 [87/91] Scraping product...
#   ✓ Success - Samsung Galaxy S25 FE 5G Smartphone with Galaxy AI... | Price: ₹67999.0 | Reviews: 41
# 📦 [88/91] Scraping product...
#   ✓ Success - Selfie Stick Tripod Portable 50" Extendable Blueto... | Price: ₹948.0 | Reviews: 76
# 📦 [89/91] Scraping product...
#   ✓ Success - Nothing Phone (3a) 5G (8GB RAM + 128GB Storage) (W... | Price: ₹24999.0 | Reviews: 500
# 📦 [90/91] Scraping product...
#   ✓ Success - realme 14 Pro+ Smartphone 12GB RAM 256GB ROM Snapd... | Price: ₹33495.0 | Reviews: 1
# 📦 [91/91] Scraping product...
#   ✓ Success - realme 15 Pro 5G Smartphone 8+256GB Green,4K 60FPS... | Price: ₹35999.0 | Reviews: 475
#
# ============================================================
# 📊 Creating DataFrame...
# Completed
