# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time
import numpy as np
from urllib.parse import urljoin
from datetime import datetime

# %%
def get_title(soup):
    try:
        # Outer Tag 
        title = soup.find("span", attrs={"id":'productTitle'})
        
        # Inner String Object
        title_value = title.text
        # Title as a string value
        title_string = title_value.strip()
    except AttributeError:
        title_string = ""
    return title_string

# %%
def get_price(soup):
    try:
        price_tag = soup.select_one("span.a-price span.a-offscreen")
        if price_tag and price_tag.text.strip():
            price_text = price_tag.text.strip()
        elif soup.find("span", {"id": "priceblock_ourprice"}):
            price_text = soup.find("span", {"id": "priceblock_ourprice"}).text.strip()
        elif soup.find("span", {"id": "priceblock_dealprice"}):
            price_text = soup.find("span", {"id": "priceblock_dealprice"}).text.strip()
        elif soup.find("span", {"id": "priceToPay"}):
            price_text = soup.find("span", {"id": "priceToPay"}).text.strip()
        elif soup.select_one("span.a-price-whole"):
            whole = soup.select_one("span.a-price-whole").text.replace(",", "").strip()
            fraction_tag = soup.select_one("span.a-price-fraction")
            fraction = fraction_tag.text.strip() if fraction_tag else "00"
            price_text = f"{whole}.{fraction}"
        else:
            return None
        cleaned_price = (
            price_text
            .replace("₹", "")
            .replace(",", "")
            .strip()
                )
        
        return float(cleaned_price)
        
    except Exception:
        return None

# %%
def get_rating(soup):
    try:
        rating = soup.find("span", {"class": "a-icon-alt"})
        return rating.text.split(" ")[0]
    except:
        return ""

# %%
def get_review_count(soup):
    try:
        # Method 1: Standard review count selector
        review = soup.find("span", {"id": "acrCustomerReviewText"})
        if review:
            review_text = review.text.strip()
            # Brackets aur commas remove karo
            review_number = review_text.split(" ")[0]
            review_number = review_number.replace(",", "").replace("(", "").replace(")", "")
            return int(review_number)
        
        # Method 2: Alternative selector for reviews
        review_alt = soup.select_one("#acrCustomerReviewLink span")
        if review_alt:
            review_text = review_alt.text.strip()
            review_number = review_text.split(" ")[0]
            review_number = review_number.replace(",", "").replace("(", "").replace(")", "")
            return int(review_number)
        
        # Method 3: Another common pattern
        review_count = soup.find("a", {"data-hook": "see-all-reviews-link-foot"})
        if review_count:
            review_text = review_count.find("span").text.strip()
            review_number = review_text.split(" ")[0]
            review_number = review_number.replace(",", "").replace("(", "").replace(")", "")
            return int(review_number)
        
        # Method 4: Check karo agar rating link mein reviews mentioned hain
        rating_link = soup.find("a", {"id": "acrCustomerReviewLink"})
        if rating_link:
            review_text = rating_link.text.strip()
            # "4.5 out of 5 stars    2,031 ratings" jaise format handle karne ke liye
            parts = review_text.split()
            for part in parts:
                cleaned = part.replace(",", "").replace("(", "").replace(")", "")
                if cleaned.isdigit():
                    num = int(cleaned)
                    if num > 10:  # Rating 10 se zyada nahi hoti, toh ye review count hoga
                        return num
            
        return 0  # Agar koi review nahi mila toh 0 return karo
        
    except Exception as e:
        print(f"  ⚠️  Review scraping error: {e}")
        return 0

# %%
def get_availability(soup):
    try:
        available = soup.find("div", attrs={'id':'availability'})
        available = available.find("span").string.strip()
    except AttributeError:
        available = "Not Available"	
    return available

# %%
def get_discount(soup):
    try:
        discount = soup.find("span", {"class": "savingsPercentage"})
        if discount:
            return discount.text.replace("%", "").replace("-", "").strip()
        return ""
    except:
        return ""

# %%
def get_brand(soup):
    try:
        brand = soup.find("a", {"id": "bylineInfo"})
        if brand:
            return brand.text.replace("Visit the", "").replace("Store", "").strip()
        # Alternative method
        brand_alt = soup.find("span", {"class": "a-size-base po-break-word"})
        if brand_alt:
            return brand_alt.text.strip()
        return ""
    except:
        return ""

# %%
if __name__ == '__main__':
    HEADERS = ({'User-Agent':'',
            'Accept-Language': 'en-US, en;q=0.5'})
    BASE_URL = "https://www.amazon.in"
    
    # Price range define karo
    MIN_PRICE = 0
    MAX_PRICE = 10000
    TOTAL_PAGES = 3
    PRICE_LABEL = "Under 10k"
    
    print("="*60)
    print(f"🔍 Amazon Smartphone Scraper - {PRICE_LABEL}")
    print(f"💰 Price Range: ₹{MIN_PRICE:,} - ₹{MAX_PRICE:,}")
    print(f"📄 Pages to Scrape: {TOTAL_PAGES}")
    print("="*60)
    
    product_links = []
    
    # Step 1: Collect all product links
    for page in range(1, TOTAL_PAGES + 1):
        print(f"\n📄 Scraping search page {page}/{TOTAL_PAGES}...")
        search_url = f"https://www.amazon.in/s?k=smartphones+under+10k&crid=3YMQSPRDU2DB&sprefix=smartphones+under+10%2Caps%2C380&ref=nb_sb_noss_2&page={page}"
        
        try:
            response = requests.get(search_url, headers=HEADERS, timeout=10)
            if response.status_code != 200:
                print(f"  ⚠️  Page {page} failed with status code: {response.status_code}")
                continue
        except requests.exceptions.RequestException as e:
            print(f"  ⚠️  Page {page} request failed: {e}")
            continue
        
        soup = BeautifulSoup(response.content, "html.parser")
        
        links = soup.find_all("a", attrs={'class':'a-link-normal s-no-outline'})
                               
        for link in links:
            href = link.get("href")
            if href and "/dp/" in href:
                product_links.append(href.split("?")[0])
        
        print(f"  ✓ Found {len(links)} products on page {page}")
        time.sleep(2)

    product_links = list(set(product_links))
    print(f"\n✅ Total unique products found: {len(product_links)}")
    print("="*60)

    data = {
        "title": [],
        "price": [],
        "rating": [],
        "reviews": [],
        "discount": [],
        "brand": [],
        "product_url": []
    }
    
    # Step 3: Scrapping each product
    print(f"\n🛒 Starting to scrape {len(product_links)} products...")
    print("="*60)
    
    successful_scrapes = 0
    failed_scrapes = 0

    for idx, link in enumerate(product_links, start=1):
        product_url = urljoin(BASE_URL, link)
        print(f"📦 [{idx}/{len(product_links)}] Scraping product...")
        
        try:
            product_page = requests.get(product_url, headers=HEADERS, timeout=10)
            if product_page.status_code != 200:
                print(f"  ❌ Failed - Status code: {product_page.status_code}")
                failed_scrapes += 1
                continue
        except Exception as e:
            print(f"  ❌ Failed - Request error: {e}")
            failed_scrapes += 1
            continue
        
        product_soup = BeautifulSoup(product_page.content, "html.parser")
        
        try:
            title = get_title(product_soup)
            cleaned_price = get_price(product_soup)
            rating = get_rating(product_soup)
            reviews = get_review_count(product_soup)
            discount = get_discount(product_soup)
            brand = get_brand(product_soup)
            
            # Data append karo
            data["title"].append(title)
            data["price"].append(cleaned_price)
            data["rating"].append(rating)
            data["reviews"].append(reviews)
            data["discount"].append(discount)
            data["brand"].append(brand)
            data["product_url"].append(product_url)
            
            # Success message with key details
            print(f"  ✓ Success - {title[:50]}... | Price: ₹{cleaned_price} | Reviews: {reviews}")
            successful_scrapes += 1
            
        except Exception as e:
            print(f"  ❌ Failed - Data extraction error: {e}")
            failed_scrapes += 1
            continue
        
        time.sleep(2)

    print("\n" + "="*60)
    print("📊 Creating DataFrame...")
    amazon_df = pd.DataFrame.from_dict(data)
    
    # Convert to proper data types
    amazon_df["price"] = pd.to_numeric(amazon_df["price"], errors="coerce")
    amazon_df["rating"] = pd.to_numeric(amazon_df["rating"], errors="coerce")
    amazon_df["reviews"] = pd.to_numeric(amazon_df["reviews"], errors="coerce")
    amazon_df["discount"] = pd.to_numeric(amazon_df["discount"], errors="coerce")
    
    # Step 5: Save to CSV
    csv_filename = f"amazon_smartphones_under_10k.csv"
    amazon_df.to_csv(csv_filename, index=False, encoding='utf-8-sig')
# Out:
# ============================================================
# 🔍 Amazon Smartphone Scraper - Under 10k
# 💰 Price Range: ₹0 - ₹10,000
# 📄 Pages to Scrape: 3
# ============================================================
#
# 📄 Scraping search page 1/3...
#   ✓ Found 25 products on page 1
#
# 📄 Scraping search page 2/3...
#   ✓ Found 22 products on page 2
#
# 📄 Scraping search page 3/3...
#   ✓ Found 22 products on page 3
#
# ✅ Total unique products found: 50
# ============================================================
#
# 🛒 Starting to scrape 50 products...
# ============================================================
# 📦 [1/50] Scraping product...
#   ✓ Success - Samsung Galaxy M07 Mobile (Black, 4GB RAM, 64GB St... | Price: ₹7499.0 | Reviews: 668
# 📦 [2/50] Scraping product...
#   ✓ Success - Tecno Spark GO 2, 4GB + 64GB, Segment 1st IP64 SGS... | Price: ₹7499.0 | Reviews: 170
# 📦 [3/50] Scraping product...
#   ✓ Success - Motorola g35 5G (Midnight Black, 128 GB) (8 GB RAM... | Price: ₹13138.0 | Reviews: 60
# 📦 [4/50] Scraping product...
#   ✓ Success - realme P3 Lite 5G (Jade Green, 4GB RAM, 128GB Stor... | Price: ₹11530.0 | Reviews: 1
# 📦 [5/50] Scraping product...
#   ✓ Success - Slide and Learn Multiplication Book for Kids | Int... | Price: ₹849.0 | Reviews: 5
# 📦 [6/50] Scraping product...
#   ✓ Success - realme NARZO N65 5G (Amber Gold 6GB RAM, 128GB Sto... | Price: ₹14999.0 | Reviews: 5260
# 📦 [7/50] Scraping product...
#   ✓ Success - Motorola G45 5G (Brilliant Blue, 8GB RAM, 128GB St... | Price: ₹12999.0 | Reviews: 2065
# 📦 [8/50] Scraping product...
#   ✓ Success - Panasonic EVOLTA YUVA Alkaline AAA Battery, Pack o... | Price: ₹199.0 | Reviews: 8
# 📦 [9/50] Scraping product...
#   ✓ Success - vivo Y19s 5G (Majestic Green, 4GB RAM, 64GB Storag... | Price: ₹12499.0 | Reviews: 29
# 📦 [10/50] Scraping product...
#   ✓ Success - vivo Y19e (Titanium Silver, 4GB RAM, 64GB Storage)... | Price: ₹9999.0 | Reviews: 575
# 📦 [11/50] Scraping product...
#   ✓ Success - Samsung Galaxy F06 5G, Bahama Blue (4GB, 128GB)... | Price: ₹9999.0 | Reviews: 591
# 📦 [12/50] Scraping product...
#   ✓ Success - Poco M7 5G Mint Green 6GB RAM|128GB ROM|SD4 Gen2 P... | Price: ₹10780.0 | Reviews: 3089
# 📦 [13/50] Scraping product...
#   ✓ Success - Oppo A6X 4G (Olive Green, 4GB RAM, 64GB Storage) w... | Price: ₹10999.0 | Reviews: 0
# 📦 [14/50] Scraping product...
#   ✓ Success - ZENO 5G AI Smartphone | 8GB RAM 128GB ROM | IP54 R... | Price: ₹9999.0 | Reviews: 85
# 📦 [15/50] Scraping product...
#   ✓ Success - Motorola G57 Power (Regatta, 8GB RAM, 128GB Storag... | Price: ₹14999.0 | Reviews: 118
# 📦 [16/50] Scraping product...
#   ✓ Success - Oppo A6X 4G (Ice Blue, 4GB RAM, 64GB Storage) with... | Price: ₹10999.0 | Reviews: 0
# 📦 [17/50] Scraping product...
#   ✓ Success - Redmi A5 Just Black (3GB RAM 64GB Storage) | Royal... | Price: ₹7999.0 | Reviews: 691
# 📦 [18/50] Scraping product...
#   ✓ Success - Samsung Galaxy F05 (Twilight Blue, 64 GB) (4 GB RA... | Price: ₹9490.0 | Reviews: 658
# 📦 [19/50] Scraping product...
#   ✓ Success - acer Super ZX 5G (Carbon Black, 8GB RAM, 128GB) | ... | Price: ₹10699.0 | Reviews: 1060
# 📦 [20/50] Scraping product...
#   ✓ Success - Motorola G06 Power (Pantone Laurel Oak, 4GB RAM, 6... | Price: ₹8340.0 | Reviews: 57
# 📦 [21/50] Scraping product...
#   ✓ Success - Samsung Galaxy A05 (Light Green, 6GB, 128GB Storag... | Price: ₹13999.0 | Reviews: 837
# 📦 [22/50] Scraping product...
#   ✓ Success - Redmi A3 (Lake Blue, 6GB RAM, 128GB Storage) | Pre... | Price: ₹9499.0 | Reviews: 47
# 📦 [23/50] Scraping product...
#   ✓ Success - ZENO 5G AI Smartphone | 8GB RAM 128GB ROM | IP54 R... | Price: ₹9999.0 | Reviews: 85
# 📦 [24/50] Scraping product...
#   ✓ Success - Poco C55 (Cool Blue, 6GB RAM, 128GB Storage)... | Price: ₹9999.0 | Reviews: 4209
# 📦 [25/50] Scraping product...
#   ✓ Success - iQOO Z10 Lite 5G (Titanium Blue, 6GB RAM, 128GB St... | Price: ₹12998.0 | Reviews: 5772
# 📦 [26/50] Scraping product...
#   ✓ Success - Redmi Note 8 (Neptune Blue, 4GB RAM, 64GB Storage)... | Price: ₹10999.0 | Reviews: 61210
# 📦 [27/50] Scraping product...
#   ✓ Success - acer Super ZX 5G (Carbon Black, 6GB RAM, 128GB) | ... | Price: ₹10198.0 | Reviews: 1060
# 📦 [28/50] Scraping product...
#   ✓ Success - REDMI 15C 5G Dusk Purple 4GB + 128GB | Royale Desi... | Price: ₹12499.0 | Reviews: 263
# 📦 [29/50] Scraping product...
#   ✓ Success - itel Zeno 20 Max | AI Vana 2.0 | 4GB RAM 128GB ROM... | Price: ₹6829.0 | Reviews: 26
# 📦 [30/50] Scraping product...
#   ✓ Success - Samsung Galaxy M06 5G Mobile (Sage Green, 4GB RAM,... | Price: ₹10999.0 | Reviews: 6451
# 📦 [31/50] Scraping product...
#   ✓ Success - realme C71 4G Smartphone 4GB+64GB Sea Blue, 6.745 ... | Price: ₹8999.0 | Reviews: 3854
# 📦 [32/50] Scraping product...
#   ✓ Success - iQOO Z10x 5G (Ultramarine, 6GB RAM, 128GB Storage)... | Price: ₹14998.0 | Reviews: 10115
# 📦 [33/50] Scraping product...
#   ✓ Success - acer Super ZX 5G (Cosmic Green, 6GB RAM, 128GB) | ... | Price: ₹10499.0 | Reviews: 1060
# 📦 [34/50] Scraping product...
#   ✓ Success - Motorola G35 5G (Midnight Black, 4+128)... | Price: ₹12242.0 | Reviews: 456
# 📦 [35/50] Scraping product...
#   ✓ Success - Redmi A3X Midnight Black 4GB RAM 128GB ROM... | Price: ₹8999.0 | Reviews: 194
# 📦 [36/50] Scraping product...
#   ✓ Success - Lava Storm Lite 5G (Cosmic Titanium, 4+4*GB RAM, 1... | Price: ₹8249.0 | Reviews: 891
# 📦 [37/50] Scraping product...
#   ✓ Success - Motorola G05 4G (Forest Green, 4+64)... | Price: ₹7899.0 | Reviews: 2431
# 📦 [38/50] Scraping product...
#   ✓ Success - POCO C75 5G, Enchanted Green (4GB, 64GB)... | Price: ₹8499.0 | Reviews: 1554
# 📦 [39/50] Scraping product...
#   ✓ Success - POCO C71, Cool Blue (4GB, 64GB)... | Price: ₹7799.0 | Reviews: 2031
# 📦 [40/50] Scraping product...
#   ✓ Success - Motorola G35 5G (Leaf Green, 4+128)... | Price: ₹11890.0 | Reviews: 560
# 📦 [41/50] Scraping product...
#   ✓ Success - realme NARZO 80 Lite 4G (Beach Gold, 6GB+128GB) | ... | Price: ₹9499.0 | Reviews: 2333
# 📦 [42/50] Scraping product...
#   ✓ Success - Motorola g35 5G (Leaf Green, 128 GB) (8 GB RAM)... | Price: ₹13138.0 | Reviews: 93
# 📦 [43/50] Scraping product...
#   ✓ Success - Motorola Moto g06 Power (Pantone Tendril, 4GB RAM,... | Price: ₹8312.0 | Reviews: 48
# 📦 [44/50] Scraping product...
#   ✓ Success - Lava Bold N1 5G (Royal Blue, 4GB RAM, 128GB Storag... | Price: ₹8249.0 | Reviews: 510
# 📦 [45/50] Scraping product...
#   ✓ Success - Redmi A4 5G (Starry Black, 4GB RAM, 128GB Storage)... | Price: ₹9999.0 | Reviews: 12168
# 📦 [46/50] Scraping product...
#   ✓ Success - realme NARZO 80 Lite 5G (Crystal Purple, 6GB+128GB... | Price: ₹12499.0 | Reviews: 3403
# 📦 [47/50] Scraping product...
#   ✓ Success - Lava Storm Play 5G (Dune Titanium, 6+6*GB RAM, 128... | Price: ₹10499.0 | Reviews: 1229
# 📦 [48/50] Scraping product...
#   ✓ Success - Lava Bold N1 Pro (Stealth Black, 4 GB RAM, 128 GB ... | Price: ₹7499.0 | Reviews: 1700
# 📦 [49/50] Scraping product...
#   ✓ Success - Tecno Spark GO 5G (Ink Black, 4GB+128GB) | Slimmes... | Price: ₹10999.0 | Reviews: 120
# 📦 [50/50] Scraping product...
#   ✓ Success - Samsung Galaxy M17 5G Mobile (Moonlight Silver, 4G... | Price: ₹13999.0 | Reviews: 1225
#
# ============================================================
# 📊 Creating DataFrame...
