# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time
import numpy as np
from urllib.parse import urljoin
from datetime import datetime

# %%
def get_title(soup):
    try:
        # Outer Tag 
        title = soup.find("span", attrs={"id":'productTitle'})
        
        # Inner String Object
        title_value = title.text
        # Title as a string value
        title_string = title_value.strip()
    except AttributeError:
        title_string = ""
    return title_string

# %%
def get_price(soup):
    try:
        price_tag = soup.select_one("span.a-price span.a-offscreen")
        if price_tag and price_tag.text.strip():
            price_text = price_tag.text.strip()
        elif soup.find("span", {"id": "priceblock_ourprice"}):
            price_text = soup.find("span", {"id": "priceblock_ourprice"}).text.strip()
        elif soup.find("span", {"id": "priceblock_dealprice"}):
            price_text = soup.find("span", {"id": "priceblock_dealprice"}).text.strip()
        elif soup.find("span", {"id": "priceToPay"}):
            price_text = soup.find("span", {"id": "priceToPay"}).text.strip()
        elif soup.select_one("span.a-price-whole"):
            whole = soup.select_one("span.a-price-whole").text.replace(",", "").strip()
            fraction_tag = soup.select_one("span.a-price-fraction")
            fraction = fraction_tag.text.strip() if fraction_tag else "00"
            price_text = f"{whole}.{fraction}"
        else:
            return None
        cleaned_price = (
            price_text
            .replace("₹", "")
            .replace(",", "")
            .strip()
                )
        
        return float(cleaned_price)
        
    except Exception:
        return None

# %%
def get_rating(soup):
    try:
        rating = soup.find("span", {"class": "a-icon-alt"})
        return rating.text.split(" ")[0]
    except:
        return ""

# %%
def get_review_count(soup):
    try:
        # Method 1: Standard review count selector
        review = soup.find("span", {"id": "acrCustomerReviewText"})
        if review:
            review_text = review.text.strip()
            # Brackets aur commas remove karo
            review_number = review_text.split(" ")[0]
            review_number = review_number.replace(",", "").replace("(", "").replace(")", "")
            return int(review_number)
        
        # Method 2: Alternative selector for reviews
        review_alt = soup.select_one("#acrCustomerReviewLink span")
        if review_alt:
            review_text = review_alt.text.strip()
            review_number = review_text.split(" ")[0]
            review_number = review_number.replace(",", "").replace("(", "").replace(")", "")
            return int(review_number)
        
        # Method 3: Another common pattern
        review_count = soup.find("a", {"data-hook": "see-all-reviews-link-foot"})
        if review_count:
            review_text = review_count.find("span").text.strip()
            review_number = review_text.split(" ")[0]
            review_number = review_number.replace(",", "").replace("(", "").replace(")", "")
            return int(review_number)
        
        # Method 4: Check karo agar rating link mein reviews mentioned hain
        rating_link = soup.find("a", {"id": "acrCustomerReviewLink"})
        if rating_link:
            review_text = rating_link.text.strip()
            # "4.5 out of 5 stars    2,031 ratings" jaise format handle karne ke liye
            parts = review_text.split()
            for part in parts:
                cleaned = part.replace(",", "").replace("(", "").replace(")", "")
                if cleaned.isdigit():
                    num = int(cleaned)
                    if num > 10:  # Rating 10 se zyada nahi hoti, toh ye review count hoga
                        return num
            
        return 0  # Agar koi review nahi mila toh 0 return karo
        
    except Exception as e:
        print(f"  ⚠️  Review scraping error: {e}")
        return 0

# %%
def get_availability(soup):
    try:
        available = soup.find("div", attrs={'id':'availability'})
        available = available.find("span").string.strip()
    except AttributeError:
        available = "Not Available"	
    return available

# %%
def get_discount(soup):
    try:
        discount = soup.find("span", {"class": "savingsPercentage"})
        if discount:
            return discount.text.replace("%", "").replace("-", "").strip()
        return ""
    except:
        return ""

# %%
def get_brand(soup):
    try:
        brand = soup.find("a", {"id": "bylineInfo"})
        if brand:
            return brand.text.replace("Visit the", "").replace("Store", "").strip()
        # Alternative method
        brand_alt = soup.find("span", {"class": "a-size-base po-break-word"})
        if brand_alt:
            return brand_alt.text.strip()
        return ""
    except:
        return ""

# %%
if __name__ == '__main__':
    HEADERS = ({'User-Agent':'',
            'Accept-Language': 'en-US, en;q=0.5'})
    BASE_URL = "https://www.amazon.in"
    SEARCH_KEYWORD = "smartphones"
    TOTAL_PAGES = 10
    
    print("="*60)
    print(f"🔍 Amazon Scraper Started - Searching for: {SEARCH_KEYWORD}")
    print("="*60)
    
    product_links = []
    
    # Step 1: Collect all product links
    for page in range(1, TOTAL_PAGES + 1):
        print(f"📄 Scraping search page {page}/{TOTAL_PAGES}...")
        search_url = f"https://www.amazon.in/s?k={SEARCH_KEYWORD}&page={page}"
        
        try:
            response = requests.get(search_url, headers=HEADERS, timeout=10)
            if response.status_code != 200:
                print(f"  ⚠️  Page {page} failed with status code: {response.status_code}")
                continue
        except requests.exceptions.RequestException as e:
            print(f"  ⚠️  Page {page} request failed: {e}")
            continue
        
        soup = BeautifulSoup(response.content, "html.parser")
        
        links = soup.find_all("a", attrs={'class':'a-link-normal s-no-outline'})
                               
        for link in links:
            href = link.get("href")
            if href and "/dp/" in href:
                product_links.append(href.split("?")[0])
        
        print(f"  ✓ Found {len(links)} products on page {page}")
        time.sleep(2)  # Be nice to Amazon servers
    
    # Remove duplicates
    product_links = list(set(product_links))
    print(f"\n✅ Total unique products found: {len(product_links)}")
    print("="*60)
    
    # Step 2: Initialize data dictionary (scrape_date removed)
    data = {
        "title": [],
        "price": [],
        "rating": [],
        "reviews": [],
        "discount": [],
        "brand": [],
        "product_url": []
    }
    
    # Step 3: Scrape each product
    print(f"\n🛒 Starting to scrape {len(product_links)} products...")
    print("="*60)
    
    successful_scrapes = 0
    failed_scrapes = 0
    
    for idx, link in enumerate(product_links, start=1):
        product_url = urljoin(BASE_URL, link)
        print(f"📦 [{idx}/{len(product_links)}] Scraping product...")
        
        try:
            product_page = requests.get(product_url, headers=HEADERS, timeout=10)
            if product_page.status_code != 200:
                print(f"  ❌ Failed - Status code: {product_page.status_code}")
                failed_scrapes += 1
                continue
        except Exception as e:
            print(f"  ❌ Failed - Request error: {e}")
            failed_scrapes += 1
            continue
        
        product_soup = BeautifulSoup(product_page.content, "html.parser")
        
        try:
            title = get_title(product_soup)
            cleaned_price = get_price(product_soup)
            rating = get_rating(product_soup)
            reviews = get_review_count(product_soup)
            discount = get_discount(product_soup)
            brand = get_brand(product_soup)
            
            # Data append karo
            data["title"].append(title)
            data["price"].append(cleaned_price)
            data["rating"].append(rating)
            data["reviews"].append(reviews)
            data["discount"].append(discount)
            data["brand"].append(brand)
            data["product_url"].append(product_url)
            
            # Success message with key details
            print(f"  ✓ Success - {title[:50]}... | Price: ₹{cleaned_price} | Reviews: {reviews}")
            successful_scrapes += 1
            
        except Exception as e:
            print(f"  ❌ Failed - Data extraction error: {e}")
            failed_scrapes += 1
            continue
        
        time.sleep(2)  # Delay to avoid getting blocked
    
    # Step 4: Create DataFrame
    print("\n" + "="*60)
    print("📊 Creating DataFrame...")
    amazon_df = pd.DataFrame.from_dict(data)
    
    # Convert to proper data types
    amazon_df["price"] = pd.to_numeric(amazon_df["price"], errors="coerce")
    amazon_df["rating"] = pd.to_numeric(amazon_df["rating"], errors="coerce")
    amazon_df["reviews"] = pd.to_numeric(amazon_df["reviews"], errors="coerce")
    amazon_df["discount"] = pd.to_numeric(amazon_df["discount"], errors="coerce")
    
    # Step 5: Save to CSV
    amazon_df.to_csv("claude_amazon_data.csv", index=False, encoding='utf-8-sig')
# Out:
# ============================================================
# 🔍 Amazon Scraper Started - Searching for: smartphones
# ============================================================
# 📄 Scraping search page 1/10...
#   ✓ Found 31 products on page 1
# 📄 Scraping search page 2/10...
#   ✓ Found 24 products on page 2
# 📄 Scraping search page 3/10...
#   ✓ Found 24 products on page 3
# 📄 Scraping search page 4/10...
#   ✓ Found 24 products on page 4
# 📄 Scraping search page 5/10...
#   ✓ Found 24 products on page 5
# 📄 Scraping search page 6/10...
#   ✓ Found 24 products on page 6
# 📄 Scraping search page 7/10...
#   ✓ Found 24 products on page 7
# 📄 Scraping search page 8/10...
#   ✓ Found 24 products on page 8
# 📄 Scraping search page 9/10...
#   ✓ Found 24 products on page 9
# 📄 Scraping search page 10/10...
#   ✓ Found 22 products on page 10
#
# ✅ Total unique products found: 168
# ============================================================
#
# 🛒 Starting to scrape 168 products...
# ============================================================
# 📦 [1/168] Scraping product...
#   ✓ Success - Pova Slim 5G (Slim White, 8GB+128GB)... | Price: ₹19999.0 | Reviews: 172
# 📦 [2/168] Scraping product...
#   ✓ Success - Samsung Galaxy F06 5G, Lit Voilet (6GB, 128GB)... | Price: ₹11890.0 | Reviews: 61
# 📦 [3/168] Scraping product...
#   ✓ Success - realme P4x 5G Smartphone, Matte Silver, 8GB RAM, 2... | Price: ₹19990.0 | Reviews: 5
# 📦 [4/168] Scraping product...
#   ✓ Success - Samsung Galaxy Z Fold7 5G Mobile with Galaxy AI (J... | Price: ₹174999.0 | Reviews: 69
# 📦 [5/168] Scraping product...
#   ✓ Success - Samsung Galaxy A35 5G (Awesome Navy, 8GB RAM, 128G... | Price: ₹19499.0 | Reviews: 576
# 📦 [6/168] Scraping product...
#   ✓ Success - OPPO A38 (Glowing Gold, 4GB RAM, 128GB Storage) | ... | Price: ₹10250.0 | Reviews: 391
# 📦 [7/168] Scraping product...
#   ✓ Success - Verilux® USB Hub for Laptop with Ethernet RJ45 7 i... | Price: ₹1547.0 | Reviews: 1080
# 📦 [8/168] Scraping product...
#   ✓ Success - Motorola Edge 60 Pro Pantone Shadow, 12GB RAM, 256... | Price: ₹33545.0 | Reviews: 158
# 📦 [9/168] Scraping product...
#   ✓ Success - Samsung Galaxy F05 (Twilight Blue, 64 GB) (4 GB RA... | Price: ₹9490.0 | Reviews: 658
# 📦 [10/168] Scraping product...
#   ✓ Success - Vivo T4x 5G (Marine Blue, 128 GB) (8 GB RAM)... | Price: ₹16499.0 | Reviews: 2780
# 📦 [11/168] Scraping product...
#   ✓ Success - Motorola Edge 60 Stylus (Web, 8+256)... | Price: ₹17857.0 | Reviews: 180
# 📦 [12/168] Scraping product...
#   ✓ Success - Motorola G04 4G (Satin Blue, 8GB RAM, 128GB Storag... | Price: ₹9999.0 | Reviews: 106
# 📦 [13/168] Scraping product...
#   ✓ Success - Verilux® USB Hub for Laptop with Ethernet RJ45 7 i... | Price: ₹1547.0 | Reviews: 1080
# 📦 [14/168] Scraping product...
#   ✓ Success - Poco M7 5G Satin Black 8GB RAM|128GB ROM|SD4 Gen2 ... | Price: ₹11799.0 | Reviews: 3089
#   ✓ Success - Verilux® USB Hub for Laptop with Ethernet RJ45 7 i... | Price: ₹1547.0 | Reviews: 1080
# 📦 [54/168] Scraping product...
#   ✓ Success - Infinix HOT 60i 5G (Sleek Black, 4GB RAM, 128GB St... | Price: ₹10999.0 | Reviews: 39
# 📦 [55/168] Scraping product...
#   ✓ Success - OnePlus 15R | 12GB+256GB | Mint Breeze | World's F... | Price: ₹47999.0 | Reviews: 632
# 📦 [56/168] Scraping product...
#   ✓ Success - Redmi A5 Just Black (4GB RAM 128GB Storage) | Roya... | Price: ₹8999.0 | Reviews: 691
# 📦 [57/168] Scraping product...
#   ✓ Success - OnePlus Nord CE5 | MediaTek Dimensity | Massive 71... | Price: ₹26999.0 | Reviews: 4599
# 📦 [58/168] Scraping product...
#   ✓ Success - CMF Phone 2 Pro 5G (Light Green, 8GB RAM, 256GB St... | Price: ₹21465.0 | Reviews: 82
# 📦 [59/168] Scraping product...
#   ✓ Success - Motorola G57 Power 5G (Regatta, 8GB RAM, 128GB Sto... | Price: ₹13989.0 | Reviews: 234
# 📦 [60/168] Scraping product...
#   ✓ Success - Lava Bold N1 Pro (Stealth Black, 4 GB RAM, 128 GB ... | Price: ₹7499.0 | Reviews: 1700
# 📦 [61/168] Scraping product...
#   ✓ Success - Vivo T4 Lite 5G Titanium Gold_128GB+6GB... | Price: ₹14390.0 | Reviews: 1718
# 📦 [62/168] Scraping product...
#   ✓ Success - iQOO Z10x 5G (Titanium, 8GB RAM, 256GB Storage) | ... | Price: ₹17998.0 | Reviews: 10115
# 📦 [63/168] Scraping product...
#   ✓ Success - Tecno Spark GO 2, 4GB + 64GB, Segment 1st IP64 SGS... | Price: ₹7499.0 | Reviews: 170
# 📦 [64/168] Scraping product...
#   ✓ Success - Motorola g35 5G (Leaf Green, 128 GB) (8 GB RAM)... | Price: ₹13140.0 | Reviews: 93
# 📦 [65/168] Scraping product...
#   ✓ Success - realme P3 Lite 5G Charger in The Box (Lily White, ... | Price: ₹13080.0 | Reviews: 26
# 📦 [66/168] Scraping product...
#   ✓ Success - Verilux® USB Hub for Laptop with Ethernet RJ45 7 i... | Price: ₹1547.0 | Reviews: 1080
# 📦 [67/168] Scraping product...
#   ✓ Success - Samsung Galaxy F06 5G (Bahama Blue, 128 GB) (6 GB ... | Price: ₹11841.0 | Reviews: 114
# 📦 [68/168] Scraping product...
#   ✓ Success - vivo T4R 5G (Twilight Blue, 256 GB) (12 GB RAM)... | Price: ₹26994.99 | Reviews: 128
# 📦 [69/168] Scraping product...
#   ✓ Success - Lava Bold N1 Lite (Crystal Blue, 3 GB RAM, 64 GB S... | Price: ₹6999.0 | Reviews: 95
# 📦 [70/168] Scraping product...
#   ✓ Success - Verilux® USB Hub for Laptop with Ethernet RJ45 7 i... | Price: ₹1547.0 | Reviews: 1080
# 📦 [71/168] Scraping product...
#   ✓ Success - Samsung Galaxy F17 5G (Violet Pop, 128 GB) (6 GB R... | Price: ₹15645.0 | Reviews: 9
# 📦 [72/168] Scraping product...
#   ✓ Success - Oppo A6X 5G (Ice Blue, 6GB RAM, 128GB Storage) wit... | Price: ₹16999.0 | Reviews: 29
# 📦 [73/168] Scraping product...
#   ✓ Success - Motorola Moto g06 Power (Pantone Tendril, 4GB RAM,... | Price: ₹8314.0 | Reviews: 48
# 📦 [74/168] Scraping product...
#   ✓ Success - iPhone 17 Pro Max 2 TB: 17.42 cm (6.9″) Display wi... | Price: ₹229900.0 | Reviews: 210
# 📦 [75/168] Scraping product...
#   ✓ Success - Lava Storm Play 5G (Dune Titanium, 8+8*GB RAM, 256... | Price: ₹13499.0 | Reviews: 1229
# 📦 [76/168] Scraping product...
#   ✓ Success - itel Zeno 20 Max | AI Vana 2.0 | 4GB RAM 128GB ROM... | Price: ₹6829.0 | Reviews: 26
# 📦 [77/168] Scraping product...
#   ✓ Success - POCO M7 Plus 5G, Chrome Silver (6GB, 128GB)... | Price: ₹13997.0 | Reviews: 33
# 📦 [78/168] Scraping product...
#   ✓ Success - Lava Agni 3 5G (Heather Glass, 8GB+256GB) | India'... | Price: ₹20999.0 | Reviews: 1620
# 📦 [79/168] Scraping product...
#   ❌ Failed - Request error: HTTPSConnectionPool(host='www.amazon.in', port=443): Read timed out.
# 📦 [80/168] Scraping product...
#   ✓ Success - Poco C75 5G Aqua Bliss|4GB RAM 128GB ROM|6.88 inch... | Price: ₹9499.0 | Reviews: 148
# 📦 [81/168] Scraping product...
#   ✓ Success - Motorola G67 Power (Pantone Blue Curacao, 8GB RAM,... | Price: ₹15919.0 | Reviews: 48
# 📦 [82/168] Scraping product...
#   ✓ Success - POCO C71, Cool Blue (6GB, 128GB)... | Price: ₹8799.0 | Reviews: 2031
# 📦 [83/168] Scraping product...
#   ✓ Success - realme NARZO 90 5G (Carbon Black,8GB+128GB) | 7000... | Price: ₹18499.0 | Reviews: 267
# 📦 [84/168] Scraping product...
#   ✓ Success - OnePlus 13 | Smarter with OnePlus AI | Lifetime Di... | Price: ₹67999.0 | Reviews: 2569
# 📦 [85/168] Scraping product...
#   ✓ Success - Motorola Edge 50 Pro (Luxe Lavender, 12+256)... | Price: ₹24578.0 | Reviews: 530
# 📦 [86/168] Scraping product...
#   ✓ Success - REDMI Note 15 5G (Glacier Blue, 8GB RAM 128GB Stor... | Price: ₹22999.0 | Reviews: 298
# 📦 [87/168] Scraping product...
#   ✓ Success - Motorola G57 Power 5G (Fluidity, 8GB RAM, 128GB St... | Price: ₹14015.0 | Reviews: 118
# 📦 [88/168] Scraping product...
#   ✓ Success - Verilux® USB Hub for Laptop with Ethernet RJ45 7 i... | Price: ₹1547.0 | Reviews: 1080
# 📦 [89/168] Scraping product...
#   ✓ Success - Tecno Spark GO 5G (Sky Blue, 4GB+128GB) | Slimmest... | Price: ₹10999.0 | Reviews: 120
# 📦 [90/168] Scraping product...
#   ✓ Success - IKALL Z10 Smartphone | 6.53” HD Display | 4GB RAM,... | Price: ₹6499.0 | Reviews: 14
# 📦 [91/168] Scraping product...
#   ✓ Success - realme 15T 5G Smartphone 8+256GB Suit Titanium,6.6... | Price: ₹24999.0 | Reviews: 1412
#   ✓ Success - OPPO K13 5G with 7000mAh and 80W SUPERVOOC Charger... | Price: ₹18667.0 | Reviews: 736
# 📦 [112/168] Scraping product...
#   ✓ Success - Samsung Galaxy S24 5G AI Smartphone (Cobalt Violet... | Price: ₹48650.0 | Reviews: 2113
# 📦 [113/168] Scraping product...
#   ✓ Success - vivo Y31 5G (Diamond Green, 4GB RAM, 128GB Storage... | Price: ₹16999.0 | Reviews: 40
# 📦 [114/168] Scraping product...
#   ✓ Success - Motorola g67 Power (Pantone Cilantro, 8GB RAM, 128... | Price: ₹15922.0 | Reviews: 33
# 📦 [115/168] Scraping product...
#   ✓ Success - Motorola G35 5G (Leaf Green, 4+128)... | Price: ₹11890.0 | Reviews: 560
# 📦 [116/168] Scraping product...
#   ✓ Success - vivo Y19e (Titanium Silver, 4GB RAM, 64GB Storage)... | Price: ₹9999.0 | Reviews: 575
# 📦 [117/168] Scraping product...
#   ✓ Success - vivo Y400 Pro 5G (Nebula Purple, 8GB RAM, 256GB St... | Price: ₹27999.0 | Reviews: 243
# 📦 [118/168] Scraping product...
#   ✓ Success - Samsung Galaxy F17 5G, Violet Pop (4GB, 128GB)... | Price: ₹13800.0 | Reviews: 24
# 📦 [119/168] Scraping product...
#   ✓ Success - REDMI Note 15 Pro+ 5G (Mirage Blue, 12GB + 512GB) ... | Price: ₹43999.0 | Reviews: 42
# 📦 [120/168] Scraping product...
#   ✓ Success - Motorola G06 Power (Pantone Laurel Oak, 4GB RAM, 6... | Price: ₹8340.0 | Reviews: 57
# 📦 [121/168] Scraping product...
#   ✓ Success - Samsung Galaxy A36 5G (Awesome Black, 12GB, 256GB)... | Price: ₹38499.0 | Reviews: 560
# 📦 [122/168] Scraping product...
#   ✓ Success - Nothing Phone (3a) Lite (White, 128 GB) (8 GB RAM)... | Price: ₹19785.0 | Reviews: 23
# 📦 [123/168] Scraping product...
#   ✓ Success - Nothing Phone (3), Black (16GB, 512 GB)... | Price: ₹55199.0 | Reviews: 18
# 📦 [124/168] Scraping product...
#   ✓ Success - OPPO K13x 5G 6000mAh and 45W SUPERVOOC Charger & A... | Price: ₹13997.0 | Reviews: 297
# 📦 [125/168] Scraping product...
#   ✓ Success - vivo X300 5G (Elite Black, 12GB RAM, 512GB Storage... | Price: ₹81998.0 | Reviews: 218
# 📦 [126/168] Scraping product...
#   ✓ Success - Oppo F31 Pro 5G (Deser Gold, 12GB RAM, 256GB Stora... | Price: ₹31999.0 | Reviews: 212
# 📦 [127/168] Scraping product...
#   ✓ Success - Samsung Galaxy S24 Snapdragon 8 Gen 3 5G (Amber Ye... | Price: ₹42994.0 | Reviews: 67
# 📦 [128/168] Scraping product...
#   ✓ Success - Samsung Galaxy A17 5G (Gray, 6GB RAM, 128GB Storag... | Price: ₹17939.0 | Reviews: 0
# 📦 [129/168] Scraping product...
#   ✓ Success - iQOO Neo 10 (Inferno Red, 16GB RAM, 512GB Storage)... | Price: ₹43998.0 | Reviews: 4350
# 📦 [130/168] Scraping product...
#   ✓ Success - iPhone Air 256 GB: Thinnest iPhone Ever, 16.63 cm ... | Price: ₹99000.0 | Reviews: 95
# 📦 [131/168] Scraping product...
#   ✓ Success - Motorola G06 (Tapestry, 4GB RAM, 64GB Storage)... | Price: ₹8146.0 | Reviews: 49
# 📦 [132/168] Scraping product...
#   ✓ Success - Poco C75 5G Enchanted Green|4GB RAM 128GB ROM|6.88... | Price: ₹9499.0 | Reviews: 54
# 📦 [133/168] Scraping product...
#   ✓ Success - realme 16 Pro 5G Smartphone 8+256GB Master Gold, 1... | Price: ₹36999.0 | Reviews: 49
# 📦 [134/168] Scraping product...
#   ✓ Success - Samsung Galaxy A35 5G (Awesome Iceblue, 8GB RAM, 1... | Price: ₹22879.0 | Reviews: 1267
# 📦 [135/168] Scraping product...
#   ✓ Success - Verilux® USB Hub for Laptop with Ethernet RJ45 7 i... | Price: ₹1547.0 | Reviews: 1080
# 📦 [136/168] Scraping product...
#   ✓ Success - OPPO K13 5G with 7000mAh and 80W SUPERVOOC Charger... | Price: ₹20831.0 | Reviews: 152
# 📦 [137/168] Scraping product...
#   ✓ Success - Samsung Galaxy A17 5G (Gray, 6GB RAM, 128GB Storag... | Price: ₹17939.0 | Reviews: 0
# 📦 [138/168] Scraping product...
#   ✓ Success - Oppo F31 5G (Bloom Red, 8GB RAM, 128GB Storage)... | Price: ₹26999.0 | Reviews: 251
# 📦 [139/168] Scraping product...
#   ✓ Success - Google Pixel 10 5G (Obsidian, 12GB RAM, 256GB Stor... | Price: ₹69660.0 | Reviews: 92
# 📦 [140/168] Scraping product...
#   ✓ Success - Samsung Galaxy A06 5G (Black, 4GB RAM, 64GB Storag... | Price: ₹11999.0 | Reviews: 396
# 📦 [141/168] Scraping product...
#   ✓ Success - realme C71 4G Smartphone 4GB+64GB Sea Blue, 6.745 ... | Price: ₹8999.0 | Reviews: 3854
# 📦 [142/168] Scraping product...
#   ✓ Success - Nokia 2660 Flip 4G Volte keypad Phone with Dual SI... | Price: ₹4699.0 | Reviews: 6688
# 📦 [143/168] Scraping product...
#   ✓ Success - Motorola Edge 60 Pro 5G (Pantone Shadow, 8GB RAM, ... | Price: ₹29749.0 | Reviews: 295
# 📦 [144/168] Scraping product...
#   ✓ Success - OPPO K13x 5G 6000mAh and 45W SUPERVOOC Charger & A... | Price: ₹14915.0 | Reviews: 44
# 📦 [145/168] Scraping product...
#   ✓ Success - Honor Magic6 Pro 5G (Epi Green, 12GB RAM, 512GB St... | Price: ₹79999.0 | Reviews: 98
# 📦 [146/168] Scraping product...
#   ✓ Success - realme P4x 5G Smartphone, Lake Green, 8GB RAM, 256... | Price: ₹19979.0 | Reviews: 7
# 📦 [147/168] Scraping product...
#   ✓ Success - Oppo Reno15c 5G (Twilight Blue, 8GB RAM, 256GB Sto... | Price: ₹34999.0 | Reviews: 7
# 📦 [148/168] Scraping product...
#   ✓ Success - Motorola G96 144Hz 3D Curved pOLED (ASHLEIGHBLUE, ... | Price: ₹17968.0 | Reviews: 248
# 📦 [149/168] Scraping product...
#   ✓ Success - realme C73 5G Smartphone 6.67 Inch Screen 120Hz 64... | Price: ₹11199.0 | Reviews: 2
# 📦 [150/168] Scraping product...
#   ✓ Success - REDMI 15 5G Frosted White 8GB + 256GB | Segment's ... | Price: ₹18499.0 | Reviews: 1343
# 📦 [151/168] Scraping product...
#   ✓ Success - Samsung Galaxy M06 5G Mobile (Sage Green, 4GB RAM,... | Price: ₹10999.0 | Reviews: 6451
# 📦 [152/168] Scraping product...
#   ✓ Success - Samsung Galaxy M56 5G Mobile (Black, 8GB RAM, 128G... | Price: ₹20999.0 | Reviews: 804
# 📦 [153/168] Scraping product...
#   ✓ Success - Samsung Galaxy M17 5G Mobile (Moonlight Silver, 8G... | Price: ₹16999.0 | Reviews: 1225
# 📦 [154/168] Scraping product...
#   ✓ Success - Nothing Phone (3), Black (12GB, 256GB)... | Price: ₹47899.0 | Reviews: 70
# 📦 [155/168] Scraping product...
#   ✓ Success - OnePlus 15 | 12GB+256GB | Sand Storm | India's Fir... | Price: ₹72998.0 | Reviews: 725
# 📦 [156/168] Scraping product...
#   ✓ Success - acer Super ZX 5G (Cosmic Green, 6GB RAM, 128GB) | ... | Price: ₹10499.0 | Reviews: 1060
# 📦 [157/168] Scraping product...
#   ✓ Success - Motorola g45 5G (Pantone Moss, 128 GB) (8 GB RAM)... | Price: ₹14499.0 | Reviews: 299
# 📦 [158/168] Scraping product...
#   ✓ Success - Samsung Galaxy M36 5G Mobile (Velvet Black, 6GB RA... | Price: ₹15999.0 | Reviews: 4088
# 📦 [159/168] Scraping product...
#   ✓ Success - iQOO Neo 10R 5G (Raging Blue, 12GB RAM, 256GB Stor... | Price: ₹30998.0 | Reviews: 6246
# 📦 [160/168] Scraping product...
#   ✓ Success - OPPO K13 5G (Prism Black, 8GB RAM 128GB Storage)... | Price: ₹18688.0 | Reviews: 561
# 📦 [161/168] Scraping product...
#   ✓ Success - Samsung Galaxy F06 5G, Bahama Blue (4GB, 128GB)... | Price: ₹9999.0 | Reviews: 591
# 📦 [162/168] Scraping product...
#   ❌ Failed - Request error: HTTPSConnectionPool(host='www.amazon.in', port=443): Read timed out.
# 📦 [163/168] Scraping product...
#   ✓ Success - OnePlus Nord 5 | Snapdragon 8s Gen 3 | Stable 144F... | Price: ₹36999.0 | Reviews: 4512
# 📦 [164/168] Scraping product...
#   ✓ Success - Samsung Galaxy A55 5G (Awesome Navy, 12GB RAM, 256... | Price: ₹29999.0 | Reviews: 5647
# 📦 [165/168] Scraping product...
#   ✓ Success - realme narzo 90 5G (Flowing Silver,6GB+128GB) | 70... | Price: ₹16999.0 | Reviews: 267
# 📦 [166/168] Scraping product...
#   ✓ Success - realme NARZO 80 Lite 4G (Beach Gold, 6GB+128GB) | ... | Price: ₹9499.0 | Reviews: 2333
# 📦 [167/168] Scraping product...
#   ✓ Success - realme P4X Smartphone 6.72 inch 144Hz Display 7000... | Price: ₹15550.0 | Reviews: 99
# 📦 [168/168] Scraping product...
#   ✓ Success - Google Pixel 9A (Obsidian, 256 GB) (8 GB RAM)... | Price: ₹38940.0 | Reviews: 367
#
# ============================================================
# 📊 Creating DataFrame...
