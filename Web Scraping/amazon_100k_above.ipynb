# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time
import numpy as np
from urllib.parse import urljoin
from datetime import datetime

def get_title(soup):
    try:
        # Outer Tag 
        title = soup.find("span", attrs={"id":'productTitle'})
        
        # Inner String Object
        title_value = title.text
        # Title as a string value
        title_string = title_value.strip()
    except AttributeError:
        title_string = ""
    return title_string

def get_price(soup):
    try:
        price_tag = soup.select_one("span.a-price span.a-offscreen")
        if price_tag and price_tag.text.strip():
            price_text = price_tag.text.strip()
        elif soup.find("span", {"id": "priceblock_ourprice"}):
            price_text = soup.find("span", {"id": "priceblock_ourprice"}).text.strip()
        elif soup.find("span", {"id": "priceblock_dealprice"}):
            price_text = soup.find("span", {"id": "priceblock_dealprice"}).text.strip()
        elif soup.find("span", {"id": "priceToPay"}):
            price_text = soup.find("span", {"id": "priceToPay"}).text.strip()
        elif soup.select_one("span.a-price-whole"):
            whole = soup.select_one("span.a-price-whole").text.replace(",", "").strip()
            fraction_tag = soup.select_one("span.a-price-fraction")
            fraction = fraction_tag.text.strip() if fraction_tag else "00"
            price_text = f"{whole}.{fraction}"
        else:
            return None
        cleaned_price = (
            price_text
            .replace("₹", "")
            .replace(",", "")
            .strip()
                )
        
        return float(cleaned_price)
        
    except Exception:
        return None

def get_rating(soup):
    try:
        rating = soup.find("span", {"class": "a-icon-alt"})
        return rating.text.split(" ")[0]
    except:
        return ""


def get_review_count(soup):
    try:
        # Method 1: Standard review count selector
        review = soup.find("span", {"id": "acrCustomerReviewText"})
        if review:
            review_text = review.text.strip()
            # Brackets aur commas remove karo
            review_number = review_text.split(" ")[0]
            review_number = review_number.replace(",", "").replace("(", "").replace(")", "")
            return int(review_number)
        
        # Method 2: Alternative selector for reviews
        review_alt = soup.select_one("#acrCustomerReviewLink span")
        if review_alt:
            review_text = review_alt.text.strip()
            review_number = review_text.split(" ")[0]
            review_number = review_number.replace(",", "").replace("(", "").replace(")", "")
            return int(review_number)
        
        # Method 3: Another common pattern
        review_count = soup.find("a", {"data-hook": "see-all-reviews-link-foot"})
        if review_count:
            review_text = review_count.find("span").text.strip()
            review_number = review_text.split(" ")[0]
            review_number = review_number.replace(",", "").replace("(", "").replace(")", "")
            return int(review_number)
        
        # Method 4: Check karo agar rating link mein reviews mentioned hain
        rating_link = soup.find("a", {"id": "acrCustomerReviewLink"})
        if rating_link:
            review_text = rating_link.text.strip()
            # "4.5 out of 5 stars    2,031 ratings" jaise format handle karne ke liye
            parts = review_text.split()
            for part in parts:
                cleaned = part.replace(",", "").replace("(", "").replace(")", "")
                if cleaned.isdigit():
                    num = int(cleaned)
                    if num > 10:  # Rating 10 se zyada nahi hoti, toh ye review count hoga
                        return num
            
        return 0  # Agar koi review nahi mila toh 0 return karo
        
    except Exception as e:
        print(f"  ⚠️  Review scraping error: {e}")
        return 0

def get_availability(soup):
    try:
        available = soup.find("div", attrs={'id':'availability'})
        available = available.find("span").string.strip()
    except AttributeError:
        available = "Not Available"	
    return available

def get_discount(soup):
    try:
        discount = soup.find("span", {"class": "savingsPercentage"})
        if discount:
            return discount.text.replace("%", "").replace("-", "").strip()
        return ""
    except:
        return ""

def get_brand(soup):
    try:
        brand = soup.find("a", {"id": "bylineInfo"})
        if brand:
            return brand.text.replace("Visit the", "").replace("Store", "").strip()
        # Alternative method
        brand_alt = soup.find("span", {"class": "a-size-base po-break-word"})
        if brand_alt:
            return brand_alt.text.strip()
        return ""
    except:
        return ""

# %%
if __name__ == '__main__':
    HEADERS = ({'User-Agent':'',
            'Accept-Language': 'en-US, en;q=0.5'})
    BASE_URL = "https://www.amazon.in"
    
    # Price range define karo - 100k+
    MIN_PRICE = 100000
    MAX_PRICE = 500000
    TOTAL_PAGES = 5
    PRICE_LABEL = "100k+"
    
    print("="*60)
    print(f"🔍 Amazon Smartphone Scraper - {PRICE_LABEL}")
    print(f"💰 Price Range: ₹{MIN_PRICE:,}+")
    print(f"📄 Pages to Scrape: {TOTAL_PAGES}")
    print("="*60)
    
    product_links = []
    
    # Step 1: Collect all product links
    for page in range(1, TOTAL_PAGES + 1):
        print(f"\n📄 Scraping search page {page}/{TOTAL_PAGES}...")
        
        # Yahan apna custom search URL daalna - page number ke saath
        search_url = f"https://www.amazon.in/s?k=iphones&crid=2HXMURGV40AJJ&sprefix=iphones%2Caps%2C371&ref=nb_sb_noss_2&page={page}"
        
        try:
            response = requests.get(search_url, headers=HEADERS, timeout=10)
            if response.status_code != 200:
                print(f"  ⚠️  Page {page} failed with status code: {response.status_code}")
                continue
        except requests.exceptions.RequestException as e:
            print(f"  ⚠️  Page {page} request failed: {e}")
            continue
        
        soup = BeautifulSoup(response.content, "html.parser")
        
        links = soup.find_all("a", attrs={'class':'a-link-normal s-no-outline'})
                               
        for link in links:
            href = link.get("href")
            if href and "/dp/" in href:
                product_links.append(href.split("?")[0])
        
        print(f"  ✓ Found {len(links)} products on page {page}")
        time.sleep(2)  # Be nice to Amazon servers
    
    # Remove duplicates
    product_links = list(set(product_links))
    print(f"\n✅ Total unique products found: {len(product_links)}")
    print("="*60)
    
    # Step 2: Initialize data dictionary
    data = {
        "title": [],
        "price": [],
        "rating": [],
        "reviews": [],
        "discount": [],
        "brand": [],
        "product_url": []
    }
    
    # Step 3: Scrape each product
    print(f"\n🛒 Starting to scrape {len(product_links)} products...")
    print("="*60)
    
    successful_scrapes = 0
    failed_scrapes = 0
    
    for idx, link in enumerate(product_links, start=1):
        product_url = urljoin(BASE_URL, link)
        print(f"📦 [{idx}/{len(product_links)}] Scraping product...")
        
        try:
            product_page = requests.get(product_url, headers=HEADERS, timeout=10)
            if product_page.status_code != 200:
                print(f"  ❌ Failed - Status code: {product_page.status_code}")
                failed_scrapes += 1
                continue
        except Exception as e:
            print(f"  ❌ Failed - Request error: {e}")
            failed_scrapes += 1
            continue
        
        product_soup = BeautifulSoup(product_page.content, "html.parser")
        
        try:
            title = get_title(product_soup)
            cleaned_price = get_price(product_soup)
            rating = get_rating(product_soup)
            reviews = get_review_count(product_soup)
            discount = get_discount(product_soup)
            brand = get_brand(product_soup)
            
            # Data append karo
            data["title"].append(title)
            data["price"].append(cleaned_price)
            data["rating"].append(rating)
            data["reviews"].append(reviews)
            data["discount"].append(discount)
            data["brand"].append(brand)
            data["product_url"].append(product_url)
            
            # Success message with key details
            print(f"  ✓ Success - {title[:50]}... | Price: ₹{cleaned_price} | Reviews: {reviews}")
            successful_scrapes += 1
            
        except Exception as e:
            print(f"  ❌ Failed - Data extraction error: {e}")
            failed_scrapes += 1
            continue
        
        time.sleep(2)  # Delay to avoid getting blocked
    
    # Step 4: Create DataFrame
    print("\n" + "="*60)
    print("📊 Creating DataFrame...")
    amazon_df = pd.DataFrame.from_dict(data)
    
    # Convert to proper data types
    amazon_df["price"] = pd.to_numeric(amazon_df["price"], errors="coerce")
    amazon_df["rating"] = pd.to_numeric(amazon_df["rating"], errors="coerce")
    amazon_df["reviews"] = pd.to_numeric(amazon_df["reviews"], errors="coerce")
    amazon_df["discount"] = pd.to_numeric(amazon_df["discount"], errors="coerce")
    
    # Step 5: Save to CSV
    csv_filename = f"amazon_smartphones_100k_plus.csv"
    amazon_df.to_csv(csv_filename, index=False, encoding='utf-8-sig')
    print("Completed")
# Out:
# ============================================================
# 🔍 Amazon Smartphone Scraper - 100k+
# 💰 Price Range: ₹100,000+
# 📄 Pages to Scrape: 5
# ============================================================
#
# 📄 Scraping search page 1/5...
#   ✓ Found 18 products on page 1
#
# 📄 Scraping search page 2/5...
#   ✓ Found 18 products on page 2
#
# 📄 Scraping search page 3/5...
#   ✓ Found 18 products on page 3
#
# 📄 Scraping search page 4/5...
#   ✓ Found 18 products on page 4
#
# 📄 Scraping search page 5/5...
#   ✓ Found 18 products on page 5
#
# ✅ Total unique products found: 84
# ============================================================
#
# 🛒 Starting to scrape 84 products...
# ============================================================
# 📦 [1/84] Scraping product...
#   ✓ Success - iPhone Air 512 GB: Thinnest iPhone Ever, 16.63 cm ... | Price: ₹113990.0 | Reviews: 95
# 📦 [2/84] Scraping product...
#   ✓ Success - OnePlus 13s | Snapdragon® 8 Elite | Smarter with O... | Price: ₹55999.0 | Reviews: 1754
# 📦 [3/84] Scraping product...
#   ✓ Success - Google Pixel 9A (Porcelain, 256 GB) (8 GB RAM)... | Price: ₹39490.0 | Reviews: 183
# 📦 [4/84] Scraping product...
#   ✓ Success - Hollyland Wireless Magnetic Mini Microphone: Lark ... | Price: ₹4099.0 | Reviews: 3674
# 📦 [5/84] Scraping product...
#   ✓ Success - SanDisk 2TB Creator Phone SSD - Up to 1,000 MB/s -... | Price: ₹32600.0 | Reviews: 98
# 📦 [6/84] Scraping product...
#   ✓ Success - Hollyland Wireless Magnetic Mini Microphone: Lark ... | Price: ₹4099.0 | Reviews: 3674
# 📦 [7/84] Scraping product...
#   ✓ Success - Apple iPhone 16 Pro Max Clear Case with MagSafe ​​... | Price: ₹4900.0 | Reviews: 4434
# 📦 [8/84] Scraping product...
#   ✓ Success - Spigen Ultra Hybrid MagFit Back Cover Case Compati... | Price: ₹1799.0 | Reviews: 50655
# 📦 [9/84] Scraping product...
#   ✓ Success - iPhone 16 Pro Max 1 TB: 5G Mobile Phone with Camer... | Price: ₹174900.0 | Reviews: 474
# 📦 [10/84] Scraping product...
#   ✓ Success - realme NARZO 90 5G (Carbon Black,6GB+128GB) | 7000... | Price: ₹16999.0 | Reviews: 267
# 📦 [11/84] Scraping product...
#   ✓ Success - ZEBRONICS MW63 Wireless Power Bank, 10000 mAh, Rap... | Price: ₹1199.0 | Reviews: 310
# 📦 [12/84] Scraping product...
#   ✓ Success - DR VAKU® 20W Charger Adapter L Cable Combo Compati... | Price: ₹629.0 | Reviews: 4707
# 📦 [13/84] Scraping product...
#   ✓ Success - Samsung Galaxy A55 5G (Awesome Navy, 12GB RAM, 256... | Price: ₹29999.0 | Reviews: 5648
# 📦 [14/84] Scraping product...
#   ✓ Success - Apple USB-C to Lightning Cable (1m) ​​​​​​​... | Price: ₹1599.0 | Reviews: 5277
# 📦 [15/84] Scraping product...
#   ✓ Success - amazon basics Luxury Paper Thin Case Cover for iPh... | Price: ₹249.0 | Reviews: 969
# 📦 [16/84] Scraping product...
#   ✓ Success - Spigen AlignMaster S Tempered Glass Screen Protect... | Price: ₹799.0 | Reviews: 175
# 📦 [17/84] Scraping product...
#   ✓ Success - Samsung Galaxy M17 5G Mobile (Sapphire Black, 6GB ... | Price: ₹15499.0 | Reviews: 1225
# 📦 [18/84] Scraping product...
#   ✓ Success - Protect+ with AppleCare Services for iPhone 14 Pro... | Price: ₹16999.0 | Reviews: 11
# 📦 [19/84] Scraping product...
#   ✓ Success - iPhone 17 Pro 1 TB: 15.93 cm (6.3″) Display with P... | Price: ₹174900.0 | Reviews: 292
# 📦 [20/84] Scraping product...
#   ✓ Success - Protective Charger Case for iPhone 18W 20W iPhone ... | Price: ₹149.0 | Reviews: 77
# 📦 [21/84] Scraping product...
#   ✓ Success - Ambrane USB To Lightning 3A Fast Charging Braided ... | Price: ₹149.0 | Reviews: 87170
# 📦 [22/84] Scraping product...
#   ✓ Success - Samsung Galaxy S24 FE 5G AI Smartphone (Graphite, ... | Price: ₹38829.0 | Reviews: 1568
# 📦 [23/84] Scraping product...
#   ✓ Success - iPhone Charger Adapter 20W Original with Lightning... | Price: ₹521.0 | Reviews: 11719
# 📦 [24/84] Scraping product...
#   ✓ Success - TheGiftKart Hybrid Matte Frosted Translucent Back ... | Price: ₹298.0 | Reviews: 1528
# 📦 [25/84] Scraping product...
#   ✓ Success - OnePlus Nord 5 | Snapdragon 8s Gen 3 | Stable 144F... | Price: ₹33999.0 | Reviews: 4512
# 📦 [26/84] Scraping product...
#   ✓ Success - TORRAS Ostand Q3 Air iPhone 17 Pro Max Case with 3... | Price: ₹8099.0 | Reviews: 1034
# 📦 [27/84] Scraping product...
#   ✓ Success - Samsung Galaxy S25 5G Smartphone with Galaxy AI (S... | Price: ₹74999.0 | Reviews: 719
# 📦 [28/84] Scraping product...
#   ✓ Success - OnePlus 13R| Smarter with OnePlus AI (12GB RAM, 25... | Price: ₹39999.0 | Reviews: 3978
# 📦 [29/84] Scraping product...
#   ✓ Success - APFEN® 80W Type C to C Fast Charging Cable [MFI Ce... | Price: ₹289.0 | Reviews: 9088
# 📦 [30/84] Scraping product...
#   ✓ Success - Hollyland Lark M2 Wireless Microphone for iPhone/C... | Price: ₹12999.0 | Reviews: 8836
# 📦 [31/84] Scraping product...
#   ✓ Success - amazon basics Luxury Paper Thin Case Cover for iPh... | Price: ₹249.0 | Reviews: 282
# 📦 [32/84] Scraping product...
#   ✓ Success - Pova Slim 5G (Slim White, 8GB+128GB)... | Price: ₹19999.0 | Reviews: 172
# 📦 [33/84] Scraping product...
#   ✓ Success - APFEN® Type C to Lightning [MFi Certified] Fast Ch... | Price: ₹273.0 | Reviews: 10258
# 📦 [34/84] Scraping product...
#   ✓ Success - Ambrane Magsafe Wireless 10000Mah Fast Charging Po... | Price: ₹1339.0 | Reviews: 6483
# 📦 [35/84] Scraping product...
#   ✓ Success - HAMMER 27W Type-C to Lightning 8 Pin Nylon Braided... | Price: ₹248.0 | Reviews: 875
# 📦 [36/84] Scraping product...
#   ✓ Success - Amazon Brand - Solimo Tempered Glass Screen Protec... | Price: ₹179.0 | Reviews: 172
# 📦 [37/84] Scraping product...
#   ✓ Success - Apple 2024 Mac mini Desktop Computer with M4 chip ... | Price: ₹77999.0 | Reviews: 69
# 📦 [38/84] Scraping product...
#   ✓ Success - Ambrane 20W Mobile Charger Adapter with Lightning ... | Price: ₹349.0 | Reviews: 4938
# 📦 [39/84] Scraping product...
#   ✓ Success - Apple iPhone 16e Silicone Case – White... | Price: ₹3900.0 | Reviews: 786
# 📦 [40/84] Scraping product...
#   ✓ Success - Hollyland Wireless Magnetic Mini Microphone: Lark ... | Price: ₹4099.0 | Reviews: 3674
# 📦 [41/84] Scraping product...
#   ✓ Success - Apple Leather Sleeve Basic Case with MagSafe for i... | Price: ₹2669.0 | Reviews: 737
# 📦 [42/84] Scraping product...
#   ✓ Success - Kratos K50 Selfie Stick Tripod with Light, 67 inch... | Price: ₹679.0 | Reviews: 2261
# 📦 [43/84] Scraping product...
#   ✓ Success - iPhone Air 1 TB: Thinnest iPhone Ever, 16.63 cm (6... | Price: ₹138890.0 | Reviews: 95
# 📦 [44/84] Scraping product...
#   ✓ Success - iPhone Charger Adapter 20W Original Lightning Cabl... | Price: ₹628.0 | Reviews: 11181
# 📦 [45/84] Scraping product...
#   ✓ Success - mobistyle iPhone 15 Back Cover Soft Liquid Silicon... | Price: ₹281.0 | Reviews: 1557
# 📦 [46/84] Scraping product...
#   ✓ Success - Samsung Galaxy M36 5G Mobile (Velvet Black, 8GB RA... | Price: ₹17499.0 | Reviews: 4088
# 📦 [47/84] Scraping product...
#   ✓ Success - Samsung Galaxy S25 Ultra 5G Mobile with Galaxy AI ... | Price: ₹129999.0 | Reviews: 941
# 📦 [48/84] Scraping product...
#   ✓ Success - USB C Cable to Lightning-20W Original [Apple-MFi C... | Price: ₹329.0 | Reviews: 6467
# 📦 [49/84] Scraping product...
#   ✓ Success - iQOO 15 (Alpha, 16GB RAM, 512GB Storage) | Fastest... | Price: ₹79998.0 | Reviews: 470
# 📦 [50/84] Scraping product...
#   ✓ Success - Apple iPhone 15 Pro Max (512 GB) - White Titanium... | Price: ₹149900.0 | Reviews: 498
# 📦 [51/84] Scraping product...
#   ✓ Success - Samsung Galaxy S25 Plus 5G (12GB RAM + 256GB Stora... | Price: ₹74994.0 | Reviews: 242
# 📦 [52/84] Scraping product...
#   ✓ Success - Portronics Konnect X USB to 8 Pin/Lightning Fast C... | Price: ₹139.0 | Reviews: 2617
# 📦 [53/84] Scraping product...
#   ✓ Success - Apple EarPods (USB-C) ​​​​​​​... | Price: ₹1649.0 | Reviews: 9681
# 📦 [54/84] Scraping product...
#   ✓ Success - Protective Charger Case for iPhone 18W 20W iPhone ... | Price: ₹149.0 | Reviews: 35
# 📦 [55/84] Scraping product...
#   ✓ Success - iPhone Air 512 GB: Thinnest iPhone Ever, 16.63 cm ... | Price: ₹113990.0 | Reviews: 95
# 📦 [56/84] Scraping product...
#   ✓ Success - Spigen Ez Fit Tempered Glass Full Screen Protector... | Price: ₹1325.0 | Reviews: 122181
# 📦 [57/84] Scraping product...
#   ✓ Success - Oppo Reno15 5G (Twilight Blue, 12GB RAM, 256GB Sto... | Price: ₹48999.0 | Reviews: 82
# 📦 [58/84] Scraping product...
#   ✓ Success - Spigen Liquid Air Back Cover Case Compatible with ... | Price: ₹930.0 | Reviews: 5470
# 📦 [59/84] Scraping product...
#   ✓ Success - iQOO Neo 10 (Titanium Chrome, 8GB RAM, 256GB Stora... | Price: ₹36998.0 | Reviews: 4350
# 📦 [60/84] Scraping product...
#   ✓ Success - DailyObjects iPhone 17 Pro Stack Classic Magnetic ... | Price: ₹1699.0 | Reviews: 52
# 📦 [61/84] Scraping product...
#   ✓ Success - Elzzi Microfiber Logo Cut Cover Compatible for iPh... | Price: ₹293.0 | Reviews: 92
# 📦 [62/84] Scraping product...
#   ✓ Success - Hollyland Wireless Magnetic Mini Microphone: Lark ... | Price: ₹4099.0 | Reviews: 3674
# 📦 [63/84] Scraping product...
#   ✓ Success - OnePlus 15R - ACE Edition | 12GB+256GB | Electric ... | Price: ₹47999.0 | Reviews: 632
# 📦 [64/84] Scraping product...
#   ✓ Success - OnePlus Nord CE5 | MediaTek Dimensity | Massive 71... | Price: ₹24999.0 | Reviews: 4599
# 📦 [65/84] Scraping product...
#   ✓ Success - TheGiftKart Ultra-Hybrid Crystal Clear Back Case C... | Price: ₹278.0 | Reviews: 17803
# 📦 [66/84] Scraping product...
#   ✓ Success - OnePlus 15 | 12GB+256GB | Ultra Violet | India's F... | Price: ₹72998.0 | Reviews: 725
# 📦 [67/84] Scraping product...
#   ✓ Success - iPhone 20W PD Fast Charger Adapter with 1 Meter Ty... | Price: ₹498.0 | Reviews: 49
# 📦 [68/84] Scraping product...
#   ✓ Success - Spigen EZ Fit Pro Tempered Glass Screen Protector ... | Price: ₹1499.0 | Reviews: 711
# 📦 [69/84] Scraping product...
#   ✓ Success - Spigen Max 30W Fast Car Charger Adapter, Budget-Fr... | Price: ₹399.0 | Reviews: 11489
# 📦 [70/84] Scraping product...
#   ✓ Success - Vivo X200 Pro 5G (Titanium Grey, 16GB RAM, 512GB S... | Price: ₹94999.0 | Reviews: 329
# 📦 [71/84] Scraping product...
#   ✓ Success - BATCHONE Back Cover for iPhone 16 | Matte Finish |... | Price: ₹249.0 | Reviews: 698
# 📦 [72/84] Scraping product...
#   ✓ Success - iPhone Charger Adapter 20W Type C (MFi-Certified) ... | Price: ₹499.0 | Reviews: 6184
# 📦 [73/84] Scraping product...
#   ✓ Success - SKYCELL Charger Case Cover with Full Cable Protect... | Price: ₹159.0 | Reviews: 1215
# 📦 [74/84] Scraping product...
#   ✓ Success - Amazon Brand - Solimo Tempered Glass Camera Lens P... | Price: ₹149.0 | Reviews: 604
# 📦 [75/84] Scraping product...
#   ✓ Success - YATWIN Silicone Case for iPhone 17, Soft-Touch, Sh... | Price: ₹299.0 | Reviews: 1
# 📦 [76/84] Scraping product...
#   ✓ Success - amazon basics Luxury Paper Thin Case Cover for iPh... | Price: ₹249.0 | Reviews: 352
# 📦 [77/84] Scraping product...
#   ✓ Success - Spigen Ultra Hybrid Back Cover Case Compatible wit... | Price: ₹1599.0 | Reviews: 18147
# 📦 [78/84] Scraping product...
#   ✓ Success - Spigen Slim Armor Back Cover Case Compatible with ... | Price: ₹1499.0 | Reviews: 28
# 📦 [79/84] Scraping product...
#   ✓ Success - CMF Phone 2 Pro 5G (Light Green, 8GB RAM, 128GB St... | Price: ₹18649.0 | Reviews: 430
# 📦 [80/84] Scraping product...
#   ✓ Success - Nothing Phone (3a) Pro 5G (Black, 8GB RAM + 256GB ... | Price: ₹32580.0 | Reviews: 245
# 📦 [81/84] Scraping product...
#   ✓ Success - iPhone 17 Pro Max 2 TB: 17.42 cm (6.9″) Display wi... | Price: ₹229900.0 | Reviews: 210
# 📦 [82/84] Scraping product...
#   ✓ Success - EGOTUDE for iPhone 17 Case | Frosted Translucent H... | Price: ₹369.0 | Reviews: 2094
# 📦 [83/84] Scraping product...
#   ✓ Success - Ambrane Type-C to Lightning USB Cable, 22.5W Fast ... | Price: ₹129.0 | Reviews: 4763
# 📦 [84/84] Scraping product...
#   ✓ Success - Protect+ with AppleCare Services for iPhone Pro Ma... | Price: ₹16999.0 | Reviews: 0
#
# ============================================================
# 📊 Creating DataFrame...
# Completed
