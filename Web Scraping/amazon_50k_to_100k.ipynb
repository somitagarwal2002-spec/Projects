# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time
import numpy as np
from urllib.parse import urljoin
from datetime import datetime

def get_title(soup):
    try:
        # Outer Tag 
        title = soup.find("span", attrs={"id":'productTitle'})
        
        # Inner String Object
        title_value = title.text
        # Title as a string value
        title_string = title_value.strip()
    except AttributeError:
        title_string = ""
    return title_string

def get_price(soup):
    try:
        price_tag = soup.select_one("span.a-price span.a-offscreen")
        if price_tag and price_tag.text.strip():
            price_text = price_tag.text.strip()
        elif soup.find("span", {"id": "priceblock_ourprice"}):
            price_text = soup.find("span", {"id": "priceblock_ourprice"}).text.strip()
        elif soup.find("span", {"id": "priceblock_dealprice"}):
            price_text = soup.find("span", {"id": "priceblock_dealprice"}).text.strip()
        elif soup.find("span", {"id": "priceToPay"}):
            price_text = soup.find("span", {"id": "priceToPay"}).text.strip()
        elif soup.select_one("span.a-price-whole"):
            whole = soup.select_one("span.a-price-whole").text.replace(",", "").strip()
            fraction_tag = soup.select_one("span.a-price-fraction")
            fraction = fraction_tag.text.strip() if fraction_tag else "00"
            price_text = f"{whole}.{fraction}"
        else:
            return None
        cleaned_price = (
            price_text
            .replace("₹", "")
            .replace(",", "")
            .strip()
                )
        
        return float(cleaned_price)
        
    except Exception:
        return None

def get_rating(soup):
    try:
        rating = soup.find("span", {"class": "a-icon-alt"})
        return rating.text.split(" ")[0]
    except:
        return ""


def get_review_count(soup):
    try:
        # Method 1: Standard review count selector
        review = soup.find("span", {"id": "acrCustomerReviewText"})
        if review:
            review_text = review.text.strip()
            # Brackets aur commas remove karo
            review_number = review_text.split(" ")[0]
            review_number = review_number.replace(",", "").replace("(", "").replace(")", "")
            return int(review_number)
        
        # Method 2: Alternative selector for reviews
        review_alt = soup.select_one("#acrCustomerReviewLink span")
        if review_alt:
            review_text = review_alt.text.strip()
            review_number = review_text.split(" ")[0]
            review_number = review_number.replace(",", "").replace("(", "").replace(")", "")
            return int(review_number)
        
        # Method 3: Another common pattern
        review_count = soup.find("a", {"data-hook": "see-all-reviews-link-foot"})
        if review_count:
            review_text = review_count.find("span").text.strip()
            review_number = review_text.split(" ")[0]
            review_number = review_number.replace(",", "").replace("(", "").replace(")", "")
            return int(review_number)
        
        # Method 4: Check karo agar rating link mein reviews mentioned hain
        rating_link = soup.find("a", {"id": "acrCustomerReviewLink"})
        if rating_link:
            review_text = rating_link.text.strip()
            # "4.5 out of 5 stars    2,031 ratings" jaise format handle karne ke liye
            parts = review_text.split()
            for part in parts:
                cleaned = part.replace(",", "").replace("(", "").replace(")", "")
                if cleaned.isdigit():
                    num = int(cleaned)
                    if num > 10:  # Rating 10 se zyada nahi hoti, toh ye review count hoga
                        return num
            
        return 0  # Agar koi review nahi mila toh 0 return karo
        
    except Exception as e:
        print(f"  ⚠️  Review scraping error: {e}")
        return 0

def get_availability(soup):
    try:
        available = soup.find("div", attrs={'id':'availability'})
        available = available.find("span").string.strip()
    except AttributeError:
        available = "Not Available"	
    return available

def get_discount(soup):
    try:
        discount = soup.find("span", {"class": "savingsPercentage"})
        if discount:
            return discount.text.replace("%", "").replace("-", "").strip()
        return ""
    except:
        return ""

def get_brand(soup):
    try:
        brand = soup.find("a", {"id": "bylineInfo"})
        if brand:
            return brand.text.replace("Visit the", "").replace("Store", "").strip()
        # Alternative method
        brand_alt = soup.find("span", {"class": "a-size-base po-break-word"})
        if brand_alt:
            return brand_alt.text.strip()
        return ""
    except:
        return ""

# %%
if __name__ == '__main__':
    HEADERS = ({'User-Agent': '',
            'Accept-Language': 'en-US, en;q=0.5'})
    BASE_URL = "https://www.amazon.in"
    
    # Price range define karo - 50k to 100k
    MIN_PRICE = 50000
    MAX_PRICE = 100000
    TOTAL_PAGES = 10
    PRICE_LABEL = "50k-100k"
    
    print("="*60)
    print(f"🔍 Amazon Smartphone Scraper - {PRICE_LABEL}")
    print(f"💰 Price Range: ₹{MIN_PRICE:,} - ₹{MAX_PRICE:,}")
    print(f"📄 Pages to Scrape: {TOTAL_PAGES}")
    print("="*60)
    
    product_links = []
    
    # Step 1: Collect all product links
    for page in range(1, TOTAL_PAGES + 1):
        print(f"\n📄 Scraping search page {page}/{TOTAL_PAGES}...")
        
        # Yahan apna custom search URL daalna - page number ke saath
        search_url = f"https://www.amazon.in/s?k=smartphones+50000+to+100000&crid=36PNZ4IGTDQDO&sprefix=smartphones+50000+to+100000%2Caps%2C480&ref=nb_sb_noss&page={page}"
        
        try:
            response = requests.get(search_url, headers=HEADERS, timeout=10)
            if response.status_code != 200:
                print(f"  ⚠️  Page {page} failed with status code: {response.status_code}")
                continue
        except requests.exceptions.RequestException as e:
            print(f"  ⚠️  Page {page} request failed: {e}")
            continue
        
        soup = BeautifulSoup(response.content, "html.parser")
        
        links = soup.find_all("a", attrs={'class':'a-link-normal s-no-outline'})
                               
        for link in links:
            href = link.get("href")
            if href and "/dp/" in href:
                product_links.append(href.split("?")[0])
        
        print(f"  ✓ Found {len(links)} products on page {page}")
        time.sleep(2)  # Be nice to Amazon servers
    
    # Remove duplicates
    product_links = list(set(product_links))
    print(f"\n✅ Total unique products found: {len(product_links)}")
    print("="*60)
    
    # Step 2: Initialize data dictionary
    data = {
        "title": [],
        "price": [],
        "rating": [],
        "reviews": [],
        "discount": [],
        "brand": [],
        "product_url": []
    }
    
    # Step 3: Scrape each product
    print(f"\n🛒 Starting to scrape {len(product_links)} products...")
    print("="*60)
    
    successful_scrapes = 0
    failed_scrapes = 0
    
    for idx, link in enumerate(product_links, start=1):
        product_url = urljoin(BASE_URL, link)
        print(f"📦 [{idx}/{len(product_links)}] Scraping product...")
        
        try:
            product_page = requests.get(product_url, headers=HEADERS, timeout=10)
            if product_page.status_code != 200:
                print(f"  ❌ Failed - Status code: {product_page.status_code}")
                failed_scrapes += 1
                continue
        except Exception as e:
            print(f"  ❌ Failed - Request error: {e}")
            failed_scrapes += 1
            continue
        
        product_soup = BeautifulSoup(product_page.content, "html.parser")
        
        try:
            title = get_title(product_soup)
            cleaned_price = get_price(product_soup)
            rating = get_rating(product_soup)
            reviews = get_review_count(product_soup)
            discount = get_discount(product_soup)
            brand = get_brand(product_soup)
            
            # Data append karo
            data["title"].append(title)
            data["price"].append(cleaned_price)
            data["rating"].append(rating)
            data["reviews"].append(reviews)
            data["discount"].append(discount)
            data["brand"].append(brand)
            data["product_url"].append(product_url)
            
            # Success message with key details
            print(f"  ✓ Success - {title[:50]}... | Price: ₹{cleaned_price} | Reviews: {reviews}")
            successful_scrapes += 1
            
        except Exception as e:
            print(f"  ❌ Failed - Data extraction error: {e}")
            failed_scrapes += 1
            continue
        
        time.sleep(2)  # Delay to avoid getting blocked
    
    # Step 4: Create DataFrame
    print("\n" + "="*60)
    print("📊 Creating DataFrame...")
    amazon_df = pd.DataFrame.from_dict(data)
    
    # Convert to proper data types
    amazon_df["price"] = pd.to_numeric(amazon_df["price"], errors="coerce")
    amazon_df["rating"] = pd.to_numeric(amazon_df["rating"], errors="coerce")
    amazon_df["reviews"] = pd.to_numeric(amazon_df["reviews"], errors="coerce")
    amazon_df["discount"] = pd.to_numeric(amazon_df["discount"], errors="coerce")
    
    # Step 5: Save to CSV
    csv_filename = f"amazon_smartphones_50k_to_100k.csv"
    amazon_df.to_csv(csv_filename, index=False, encoding='utf-8-sig')
    print("Completed")
# Out:
# ============================================================
# 🔍 Amazon Smartphone Scraper - 50k-100k
# 💰 Price Range: ₹50,000 - ₹100,000
# 📄 Pages to Scrape: 10
# ============================================================
#
# 📄 Scraping search page 1/10...
#   ✓ Found 25 products on page 1
#
# 📄 Scraping search page 2/10...
#   ✓ Found 21 products on page 2
#
# 📄 Scraping search page 3/10...
#   ✓ Found 17 products on page 3
#
# 📄 Scraping search page 4/10...
#   ✓ Found 5 products on page 4
#
# 📄 Scraping search page 5/10...
#   ✓ Found 5 products on page 5
#
# 📄 Scraping search page 6/10...
#   ✓ Found 5 products on page 6
#
# 📄 Scraping search page 7/10...
#   ✓ Found 5 products on page 7
#
# 📄 Scraping search page 8/10...
#   ✓ Found 5 products on page 8
#
# 📄 Scraping search page 9/10...
#   ✓ Found 5 products on page 9
#
# 📄 Scraping search page 10/10...
#   ✓ Found 5 products on page 10
#
# ✅ Total unique products found: 43
# ============================================================
#
# 🛒 Starting to scrape 43 products...
# ============================================================
# 📦 [1/43] Scraping product...
#   ✓ Success - OnePlus 13 | Smarter with OnePlus AI | Lifetime Di... | Price: ₹60999.0 | Reviews: 2569
# 📦 [2/43] Scraping product...
#   ✓ Success - Total Damage & Theft Protection Plan for Smartphon... | Price: ₹7125.0 | Reviews: 8
# 📦 [3/43] Scraping product...
#   ✓ Success - OnePlus 15R | 12GB+256GB | Charcoal Black | World'... | Price: ₹47999.0 | Reviews: 632
# 📦 [4/43] Scraping product...
#   ✓ Success - OnePlus Nord 5 | Snapdragon 8s Gen 3 | Stable 144F... | Price: ₹36999.0 | Reviews: 4512
# 📦 [5/43] Scraping product...
#   ✓ Success - Nothing Phone (3), Black (16GB, 512 GB)... | Price: ₹55199.0 | Reviews: 18
# 📦 [6/43] Scraping product...
#   ✓ Success - iQOO 13 5G (Legend, 16GB RAM, 512GB Storage)... | Price: ₹59999.0 | Reviews: 2724
# 📦 [7/43] Scraping product...
#   ✓ Success - Samsung Galaxy S25 FE 5G Smartphone with Galaxy AI... | Price: ₹67999.0 | Reviews: 41
# 📦 [8/43] Scraping product...
#   ✓ Success - Samsung Galaxy A36 5G (Awesome Black, 8GB, 256GB) ... | Price: ₹35499.0 | Reviews: 560
# 📦 [9/43] Scraping product...
#   ✓ Success - VIVO X90 Pro (Legendary Black) – 12GB RAM, 256GB S... | Price: ₹54990.0 | Reviews: 2
# 📦 [10/43] Scraping product...
#   ✓ Success - iQOO 15 (Alpha, 16GB RAM, 512GB Storage) | Fastest... | Price: ₹79998.0 | Reviews: 470
# 📦 [11/43] Scraping product...
#   ✓ Success - VIVO X Fold5 (Titanium Gray, 16GB RAM, 512GB Stora... | Price: ₹149998.0 | Reviews: 61
# 📦 [12/43] Scraping product...
#   ✓ Success - Google Pixel 10 Pro Fold (Moonstone, 256 GB) (16 G... | Price: ₹149447.0 | Reviews: 2
# 📦 [13/43] Scraping product...
#   ✓ Success - Vivo X200 Pro 5G (Titanium Grey, 16GB RAM, 512GB S... | Price: ₹94999.0 | Reviews: 329
# 📦 [14/43] Scraping product...
#   ✓ Success - Samsung Galaxy S24 Plus 5G AI Smartphone (Cobalt V... | Price: ₹72490.0 | Reviews: 348
# 📦 [15/43] Scraping product...
#   ✓ Success - Nothing Phone (3), White (16GB, 512GB)... | Price: ₹54900.0 | Reviews: 6
# 📦 [16/43] Scraping product...
#   ✓ Success - iQOO 11 5G (Alpha, 16GB RAM, 256 GB Storage) | Sna... | Price: ₹44999.0 | Reviews: 1289
# 📦 [17/43] Scraping product...
#   ✓ Success - 1 Year Insurance Plan/Accident Protection Plan/Scr... | Price: ₹6699.0 | Reviews: 90
# 📦 [18/43] Scraping product...
#   ✓ Success - Google Pixel 10 Pro XL (Obsidian, 256 GB) (16 GB R... | Price: ₹119990.0 | Reviews: 4
# 📦 [19/43] Scraping product...
#   ✓ Success - OnePlus 13R| Smarter with OnePlus AI (12GB RAM, 25... | Price: ₹39999.0 | Reviews: 3978
# 📦 [20/43] Scraping product...
#   ✓ Success - iQOO Z10 5G (Stellar Black, 12GB RAM, 256GB Storag... | Price: ₹24998.0 | Reviews: 4582
# 📦 [21/43] Scraping product...
#   ✓ Success - Samsung Galaxy A55 5G (Awesome Navy, 8GB RAM, 256G... | Price: ₹27999.0 | Reviews: 5648
# 📦 [22/43] Scraping product...
#   ✓ Success - VIVO X200 Pro 5G (16GB RAM | 512GB Storage | Cosmo... | Price: ₹79999.0 | Reviews: 1
# 📦 [23/43] Scraping product...
#   ✓ Success - Samsung Galaxy S25+ 5G AI Smartphone (Navy, 12GB R... | Price: ₹99999.0 | Reviews: 242
# 📦 [24/43] Scraping product...
#   ✓ Success - Redmi Note 9 Pro (Glacier White, 4GB RAM, 64GB Sto... | Price: ₹13999.0 | Reviews: 137328
# 📦 [25/43] Scraping product...
#   ✓ Success - Samsung Galaxy S23 5G AI Smartphone (Lavender, 8GB... | Price: ₹9999.0 | Reviews: 118
# 📦 [26/43] Scraping product...
#   ✓ Success - OnePlus 11R 5G (Galactic Silver, 8GB RAM, 128GB St... | Price: ₹34499.0 | Reviews: 21449
# 📦 [27/43] Scraping product...
#   ✓ Success - Samsung Galaxy S24 Plus 5G AI Smartphone (Onyx Bla... | Price: ₹71490.0 | Reviews: 348
# 📦 [28/43] Scraping product...
#   ✓ Success - Samsung Galaxy S25 5G Smartphone with Galaxy AI (I... | Price: ₹74999.0 | Reviews: 719
# 📦 [29/43] Scraping product...
#   ✓ Success - iQOO Neo 10R 5G (Moonknight Titanium, 12GB RAM, 25... | Price: ₹30998.0 | Reviews: 6246
# 📦 [30/43] Scraping product...
#   ✓ Success - Samsung Galaxy S25 FE 5G Smartphone with Galaxy AI... | Price: ₹57990.0 | Reviews: 41
# 📦 [31/43] Scraping product...
#   ✓ Success - Total Damage & Theft Protection Plan for Smartphon... | Price: ₹10499.0 | Reviews: 8
# 📦 [32/43] Scraping product...
#   ✓ Success - OnePlus 11R 5G (Galactic Silver, 16GB RAM, 256GB S... | Price: ₹37999.0 | Reviews: 21449
# 📦 [33/43] Scraping product...
#   ✓ Success - iQOO Z10R 5G (Aquamarine, 12GB RAM, 256GB Storage)... | Price: ₹24998.0 | Reviews: 3466
# 📦 [34/43] Scraping product...
#   ✓ Success - iQOO Neo 10 (Inferno Red, 16GB RAM, 512GB Storage)... | Price: ₹43998.0 | Reviews: 4350
# 📦 [35/43] Scraping product...
#   ✓ Success - Samsung Galaxy Z Flip5 5G AI Smartphone (Graphite,... | Price: ₹57999.0 | Reviews: 89
# 📦 [36/43] Scraping product...
#   ✓ Success - Nothing Phone (3) 5G (White, 12GB RAM + 256GB Stor... | Price: ₹58950.0 | Reviews: 0
# 📦 [37/43] Scraping product...
#   ✓ Success - OnePlus 10T 5G (Jade Green, 8GB RAM, 128GB Storage... | Price: ₹32999.0 | Reviews: 4891
# 📦 [38/43] Scraping product...
#   ✓ Success - OnePlus 15 | 16GB+512GB | Sand Storm | India's Fir... | Price: ₹79999.0 | Reviews: 725
# 📦 [39/43] Scraping product...
#   ✓ Success - Samsung Galaxy S23 5G AI Smartphone (Cream, 8GB, 2... | Price: ₹67990.0 | Reviews: 2100
# 📦 [40/43] Scraping product...
#   ✓ Success - iQOO 12 5G (Desert Red, 16GB RAM, 512GB Storage)... | Price: ₹44999.0 | Reviews: 3981
# 📦 [41/43] Scraping product...
#   ✓ Success - Samsung Galaxy S25 Plus 5G (12GB RAM + 256GB Stora... | Price: ₹74994.0 | Reviews: 242
# 📦 [42/43] Scraping product...
#   ✓ Success - Motorola Signature (Pantone Carbon, 16GB RAM +512G... | Price: ₹63399.0 | Reviews: 0
# 📦 [43/43] Scraping product...
#   ✓ Success - Samsung Galaxy S25 Ultra 5G (Titanium Gray, 12GB R... | Price: ₹113890.0 | Reviews: 13
#
# ============================================================
# 📊 Creating DataFrame...
# Completed
